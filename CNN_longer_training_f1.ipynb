# %%
import keras.utils
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPool2D, BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import Sequence
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
import tensorflow.keras.backend as K
from sklearn.metrics import accuracy_score, balanced_accuracy_score, f1_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import matplotlib.pyplot as plt
import os
import json

# %% [markdown]
# # Import data

# %%
variable = {'phF': 0, 'MF': 1}['phF'] # TODO: for now just classify one variable

# %%
VARIABLES = ['ActivityCounts', 'Barometer', 'BloodPerfusion',
             'BloodPulseWave', 'EnergyExpenditure', 'HR',
             'HRV', 'RESP', 'Steps', 'SkinTemperature']

# %%
path = './Output'

# %%
# dimensions
N, HEIGHT, WIDTH, CHANNELS = sum([1 for p in os.listdir(path) if p[:14] == 'feature_vector']), \
                             *np.load(path + '/feature_vector0.npy').shape

# metadata (subjectID etc.)
with open(path + '/metadata.txt') as f:
    metadata = f.read()
metadata = json.loads(metadata.replace('\'', '\"').replace('False', 'false').replace('True', 'true')) # doesn't accept other chars

# %% [markdown]
# # Train/validation split

# %%
VALIDATION_SIZE = 0.2

# %%
# use unaugmented data for validation set
non_augmented = [i for i, meta in enumerate(metadata) if meta['augmented'] == False]

validation_indices = np.random.choice(non_augmented, int(N * VALIDATION_SIZE), replace=False)
training_indices = np.delete(np.arange(N), validation_indices)

# %%
print(f'Training set: {len(training_indices)}')
print(f'Validation set: {len(validation_indices)}')
# Out:
# Training set: 2478
# Validation set: 619

# %% [markdown]
# # Define data generator

# %%
class DataGenerator(Sequence):

    def __init__(self, data_path: str, indices_dataset: list, batch_size=32, dim=(HEIGHT, WIDTH), n_channels=CHANNELS, shuffle=True):
        self.data_path = data_path # path to full dataset
        self.dim = dim # image dimension
        self.batch_size = batch_size
        self.indices_dataset = indices_dataset # indices of full dataset (different for train/validation/test set)
        self.n_channels = n_channels
        self.shuffle = shuffle

        self.on_epoch_end() # shuffle data for each epoch

    def on_epoch_end(self):
        """
        Shuffle data for each epoch
        """
        if self.shuffle:
            np.random.shuffle(self.indices_dataset)

    def __data_generation(self, indices):
        """
        Loads and returns datapoints[indices]
        """
        # init
        X = np.empty((self.batch_size, *self.dim, self.n_channels))
        y = np.empty(self.batch_size, dtype=float) # TODO: int for non-logits

        # load individual datapoints
        for i, index in enumerate(indices):
            X[i, ] = np.load(self.data_path + f'/feature_vector{index}.npy', allow_pickle=True)
            y[i] = np.load(self.data_path + f'/labels{index}.npy', allow_pickle=True)[variable] # TODO: for now just one variable

        return X, y

    def __len__(self):
        """
        Number of batches per epoch
        """
        return int(np.floor(len(self.indices_dataset) / self.batch_size))

    def __getitem__(self, index):
        """
        Generates batch[index]
        """
        # calculate indices of batch
        indices = self.indices_dataset[index * self.batch_size:(index + 1) * self.batch_size]

        # generate batch
        X, y = self.__data_generation(indices)

        return X, y

# %% [markdown]
# # Upsampling

# %%
UPSAMPLING_STRATEGY = 'nothing' # ['repeat', 'nothing']

# %%
def check_imbalance(path_to_labels, indices):
    """Returns indices of positives/negatives"""
    y = np.empty((len(indices), 2), dtype=int)
    for i, index in enumerate(indices):
        y[i, ] = np.load(path_to_labels + f'/labels{index}.npy', allow_pickle=True)

    positives = np.where(y[:, variable] == 1)[0] # TODO: for now just one variable
    negatives = np.where(y[:, variable] == 0)[0] # TODO: for now just one variable

    return np.array(indices)[positives], np.array(indices)[negatives]


# validation set
positives, negatives = check_imbalance(path, validation_indices)
print(f'validation: (+: {len(positives)}, -: {len(negatives)})')

# training set
positives, negatives = check_imbalance(path, training_indices)
print(f'train_set: (+: {len(positives)}, -: {len(negatives)})')

sample_weight = len(negatives) / len(positives) # for weighted cross-entropy

# upsampling training set
if UPSAMPLING_STRATEGY == 'repeat':
    upsampled_indices = np.random.choice(negatives, size=(len(positives) - len(negatives)), replace=True) # with replacement
    upsampled_indices = np.append(upsampled_indices, np.arange(N))
    training_indices = np.append(positives, negatives) # update

    positives, negatives = check_imbalance(path, upsampled_indices)
    print(f'train_set (upsampled): (+: {len(positives)}, -: {len(negatives)})')
if UPSAMPLING_STRATEGY == 'nothing':
    pass

print(f'\nWeighted loss function: weight = {sample_weight}')
# Out:
# validation: (+: 457, -: 162)
# train_set: (+: 1835, -: 643)
#
# Weighted loss function: weight = 0.35040871934604906

# %% [markdown]
# # CNN

# %% [markdown]
# Data generators

# %%
training_batch_generator = DataGenerator(data_path=path, indices_dataset=training_indices, batch_size=128)
validation_batch_generator = DataGenerator(data_path=path, indices_dataset=validation_indices, batch_size=32) # TODO: use test set to avoid mixing

# %% [markdown]
# Model

# %%
# wrapper functions
def weighted_cross_entropy(weight):
    def weighted_cross_entropy_with_logits(labels, logits):
        loss = tf.nn.weighted_cross_entropy_with_logits(
            labels, logits, weight
        )
        return loss
    return weighted_cross_entropy_with_logits


class accuracy_with_logits(tf.keras.metrics.Accuracy):

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.round(tf.math.sigmoid(y_pred))
        return super(accuracy_with_logits, self).update_state(y_true, y_pred, sample_weight)

class recall_with_logits(tf.keras.metrics.Recall):

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.round(tf.math.sigmoid(y_pred))
        return super(recall_with_logits, self).update_state(y_true, y_pred, sample_weight)

class precision_with_logits(tf.keras.metrics.Precision):

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.round(tf.math.sigmoid(y_pred))
        return super(precision_with_logits, self).update_state(y_true, y_pred, sample_weight)

class BalancedAccuracy(tf.keras.metrics.Metric):

    def __init__(self, name='balanced_accuracy', **kwargs):
        super(BalancedAccuracy, self).__init__(name=name, **kwargs)
        self.recall = self.add_weight(name="ctp", initializer="zeros")
        self.specificity = self.add_weight(name="ctp", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.round(tf.math.sigmoid(y_pred))

        tp = K.sum(y_true * y_pred)
        tn = K.sum((1 - y_true) * (1 - y_pred))
        fp = K.sum((1 - y_true) * y_pred)
        fn = K.sum(y_true * (1 - y_pred))

        self.recall.assign(tp / (tp + fn + K.epsilon()))
        self.specificity.assign(tn / (tn + fp + K.epsilon()))

    def result(self):
        return 0.5 * (self.recall + self.specificity)

    def reset_state(self):
        # The state of the metric will be reset at the start of each epoch.
        self.recall.assign(0.0)
        self.specificity.assign(0.0)

class MCC(tf.keras.metrics.Metric):

    def __init__(self, name='mcc', **kwargs):
        super(MCC, self).__init__(name=name, **kwargs)
        self.tp = self.add_weight(name="ctp", initializer="zeros")
        self.tn = self.add_weight(name="ctp", initializer="zeros")
        self.fp = self.add_weight(name="ctp", initializer="zeros")
        self.fn = self.add_weight(name="ctp", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.round(tf.math.sigmoid(y_pred))

        self.tp = K.sum(y_true * y_pred)
        self.tn = K.sum((1 - y_true) * (1 - y_pred))
        self.fp = K.sum((1 - y_true) * y_pred)
        self.fn = K.sum(y_true * (1 - y_pred))

    def result(self):
        return abs((self.tp * self.tn - self.fp * self.fn) /
                   ((self.tp + self.fp) * (self.tp + self.fn) * (self.tn + self.fp) * (self.tn + self.fn) + K.epsilon())**0.5)

    def reset_state(self):
        # The state of the metric will be reset at the start of each epoch.
        self.tp = 0.0
        self.tn = 0.0
        self.fp = 0.0
        self.fn = 0.0

class F1(tf.keras.metrics.Metric):

    def __init__(self, name='f1', **kwargs):
        super(F1, self).__init__(name=name, **kwargs)
        self.tp = self.add_weight(name="ctp", initializer="zeros")
        self.tn = self.add_weight(name="ctp", initializer="zeros")
        self.fp = self.add_weight(name="ctp", initializer="zeros")
        self.fn = self.add_weight(name="ctp", initializer="zeros")

        self.positives = self.add_weight(name="ctp", initializer="zeros")
        self.positives_pred = self.add_weight(name="ctp", initializer="zeros")
        self.negatives = self.add_weight(name="ctp", initializer="zeros")
        self.negatives_pred = self.add_weight(name="ctp", initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.round(tf.math.sigmoid(y_pred))

        self.positives = K.sum(y_true)
        self.positives_pred = K.sum(y_pred)
        self.negatives = K.sum((1 - y_true))
        self.negatives_pred = K.sum((1 - y_pred))

        self.tp = K.sum(y_true * y_pred)
        self.tn = K.sum((1 - y_true) * (1 - y_pred))
        self.fp = K.sum((1 - y_true) * y_pred)
        self.fn = K.sum(y_true * (1 - y_pred))

    def result(self):
        precision = self.tp / (self.positives_pred + K.epsilon())
        recall = self.tp / (self.positives + K.epsilon())
        f1 = 2 * (precision * recall) / (precision + recall + K.epsilon())

        precision_negatives = self.tn / (self.negatives_pred + K.epsilon())
        recall_negatives = self.tn / (self.negatives + K.epsilon())
        f1_negatives = 2 * (precision_negatives * recall_negatives) / (precision_negatives + recall_negatives + K.epsilon())

        return (self.positives * f1 + self.negatives * f1_negatives) / (self.positives + self.negatives + K.epsilon())

    def reset_state(self):
        # The state of the metric will be reset at the start of each epoch.
        self.positives = 0.0
        self.positives_pred = 0.0
        self.negatives = 0.0
        self.negatives_pred = 0.0

        self.tp = 0.0
        self.tn = 0.0
        self.fp = 0.0
        self.fn = 0.0

# %%
model = models.Sequential(name='custom_CNN')

model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=(HEIGHT, WIDTH, CHANNELS), padding='same', name='conv1-1'))
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same', name='conv1-2'))
model.add(BatchNormalization(name='batch_norm1')) # try for incr. stability
model.add(MaxPool2D(strides=(2, 2), name='pool1'))

model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same', name='conv2-1'))
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same', name='conv2-2'))
model.add(BatchNormalization(name='batch_norm2')) # try for incr. stability
model.add(MaxPool2D(strides=(2, 2), name='pool2'))

model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same', name='conv3-1'))
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same', name='conv3-2'))
model.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same', name='conv3-3'))
model.add(BatchNormalization(name='batch_norm3')) # try for incr. stability
model.add(MaxPool2D(strides=(2, 2), name='pool3'))

model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same', name='conv4-1'))
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same', name='conv4-2'))
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same', name='conv4-3'))
model.add(BatchNormalization(name='batch_norm4')) # try for incr. stability
model.add(MaxPool2D(strides=(2, 2), name='pool4'))

model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same', name='conv5-1'))
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same', name='conv5-2'))
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same', name='conv5-3'))
model.add(BatchNormalization(name='batch_norm5')) # try for incr. stability
model.add(MaxPool2D(strides=(2, 2), name='pool5'))

model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same', name='conv6-1'))
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same', name='conv6-2'))
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same', name='conv6-3'))
model.add(BatchNormalization(name='batch_norm6')) # try for incr. stability
model.add(MaxPool2D(strides=(2, 2), name='pool6'))

model.add(Flatten(name='flatten'))
model.add(Dense(128, activation='relu', kernel_initializer='random_normal', bias_initializer='zeros', kernel_regularizer='l2', name='dense1'))
model.add(Dropout(0.4, name='dropout1')) # TODO: worth it? parameter scale adequate?
model.add(Dense(64, activation='relu', kernel_initializer='random_normal', bias_initializer='zeros', kernel_regularizer='l2', name='dense2'))
model.add(Dropout(0.3, name='dropout2')) # TODO: worth it? parameter scale adequate?
model.add(Dense(1, kernel_regularizer='l2', name='dense3'))

model.compile(optimizer=Adam(learning_rate=1e-5), loss=weighted_cross_entropy(sample_weight), metrics=[accuracy_with_logits(),
                                                                                                       recall_with_logits(),
                                                                                                       precision_with_logits(),
                                                                                                       BalancedAccuracy(),
                                                                                                       MCC(),
                                                                                                       F1()])

model.summary()
# Out:
# Model: "custom_CNN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1-1 (Conv2D)             (None, 370, 100, 16)      4336
# _________________________________________________________________
# conv1-2 (Conv2D)             (None, 370, 100, 16)      2320
# _________________________________________________________________
# batch_norm1 (BatchNormalizat (None, 370, 100, 16)      64
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 185, 50, 16)       0
# _________________________________________________________________
# conv2-1 (Conv2D)             (None, 185, 50, 16)       2320
# _________________________________________________________________
# conv2-2 (Conv2D)             (None, 185, 50, 16)       2320
# _________________________________________________________________
# batch_norm2 (BatchNormalizat (None, 185, 50, 16)       64
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 92, 25, 16)        0
# _________________________________________________________________
# conv3-1 (Conv2D)             (None, 92, 25, 16)        2320
# _________________________________________________________________
# conv3-2 (Conv2D)             (None, 92, 25, 16)        2320
# _________________________________________________________________
# conv3-3 (Conv2D)             (None, 92, 25, 16)        2320
# _________________________________________________________________
# batch_norm3 (BatchNormalizat (None, 92, 25, 16)        64
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 46, 12, 16)        0
# _________________________________________________________________
# conv4-1 (Conv2D)             (None, 46, 12, 32)        4640
# _________________________________________________________________
# conv4-2 (Conv2D)             (None, 46, 12, 32)        9248
# _________________________________________________________________
# conv4-3 (Conv2D)             (None, 46, 12, 32)        9248
# _________________________________________________________________
# batch_norm4 (BatchNormalizat (None, 46, 12, 32)        128
# _________________________________________________________________
# pool4 (MaxPooling2D)         (None, 23, 6, 32)         0
# _________________________________________________________________
# conv5-1 (Conv2D)             (None, 23, 6, 32)         9248
# _________________________________________________________________
# conv5-2 (Conv2D)             (None, 23, 6, 32)         9248
# _________________________________________________________________
# conv5-3 (Conv2D)             (None, 23, 6, 32)         9248
# _________________________________________________________________
# batch_norm5 (BatchNormalizat (None, 23, 6, 32)         128
# _________________________________________________________________
# pool5 (MaxPooling2D)         (None, 11, 3, 32)         0
# _________________________________________________________________
# conv6-1 (Conv2D)             (None, 11, 3, 32)         9248
# _________________________________________________________________
# conv6-2 (Conv2D)             (None, 11, 3, 32)         9248
# _________________________________________________________________
# conv6-3 (Conv2D)             (None, 11, 3, 32)         9248
# _________________________________________________________________
# batch_norm6 (BatchNormalizat (None, 11, 3, 32)         128
# _________________________________________________________________
# pool6 (MaxPooling2D)         (None, 5, 1, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 160)               0
# _________________________________________________________________
# dense1 (Dense)               (None, 128)               20608
# _________________________________________________________________
# dropout1 (Dropout)           (None, 128)               0
# _________________________________________________________________
# dense2 (Dense)               (None, 64)                8256
# _________________________________________________________________
# dropout2 (Dropout)           (None, 64)                0
# _________________________________________________________________
# dense3 (Dense)               (None, 1)                 65
# =================================================================
# Total params: 126,385
# Trainable params: 126,097
# Non-trainable params: 288
# _________________________________________________________________

# %% [markdown]
# Training

# %%
# %%time
# save best performing model
checkpoint_path_mcc = './temp/checkpoint_model_mcc'
model_checkpoint_callback_mcc = ModelCheckpoint(filepath=checkpoint_path_mcc,
                                            save_weights_only=True,
                                            monitor='val_mcc',
                                            save_best_only=True)
checkpoint_path_f1 = './temp/checkpoint_model_f1'
model_checkpoint_callback_f1 = ModelCheckpoint(filepath=checkpoint_path_f1,
                                            save_weights_only=True,
                                            monitor='val_f1',
                                            save_best_only=True)

# train
history = model.fit_generator(generator=training_batch_generator,
                              validation_data=validation_batch_generator,
                              epochs=200,
                              callbacks=[model_checkpoint_callback_mcc, model_checkpoint_callback_f1])
# Out:
# Epoch 1/200
# 19/19 [==============================] - 51s 3s/step - loss: 1.1062 - accuracy: 0.6476 - recall_with_logits_4: 0.7888 - precision_with_logits_4: 0.7484 - balanced_accuracy: 0.5379 - mcc: 0.0748 - f1: 0.6817 - val_loss: 1.0962 - val_accuracy: 0.7401 - val_recall_with_logits_4: 1.0000 - val_precision_with_logits_4: 0.7401 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.8167
# Epoch 2/200
# 19/19 [==============================] - 47s 3s/step - loss: 1.1068 - accuracy: 0.6086 - recall_with_logits_4: 0.7419 - precision_with_logits_4: 0.7322 - balanced_accuracy: 0.5190 - mcc: 0.0358 - f1: 0.5990 - val_loss: 1.0950 - val_accuracy: 0.7368 - val_recall_with_logits_4: 1.0000 - val_precision_with_logits_4: 0.7368 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.6853
# Epoch 3/200
# 19/19 [==============================] - 48s 3s/step - loss: 1.0976 - accuracy: 0.6254 - recall_with_logits_4: 0.7300 - precision_with_logits_4: 0.7547 - balanced_accuracy: 0.5293 - mcc: 0.0553 - f1: 0.6740 - val_loss: 1.0915 - val_accuracy: 0.7385 - val_recall_with_logits_4: 1.0000 - val_precision_with_logits_4: 0.7385 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.6429
# Epoch 4/200
# 19/19 [==============================] - 49s 3s/step - loss: 1.0957 - accuracy: 0.6053 - recall_with_logits_4: 0.7048 - precision_with_logits_4: 0.7472 - balanced_accuracy: 0.5186 - mcc: 0.0327 - f1: 0.6337 - val_loss: 1.0889 - val_accuracy: 0.7385 - val_recall_with_logits_4: 1.0000 - val_precision_with_logits_4: 0.7385 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.6429
# Epoch 5/200
# 19/19 [==============================] - 52s 3s/step - loss: 1.0903 - accuracy: 0.5917 - recall_with_logits_4: 0.6768 - precision_with_logits_4: 0.7479 - balanced_accuracy: 0.4896 - mcc: 0.0197 - f1: 0.6046 - val_loss: 1.0847 - val_accuracy: 0.7418 - val_recall_with_logits_4: 1.0000 - val_precision_with_logits_4: 0.7418 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.5200
# Epoch 6/200
# 19/19 [==============================] - 47s 3s/step - loss: 1.0894 - accuracy: 0.5905 - recall_with_logits_4: 0.6781 - precision_with_logits_4: 0.7460 - balanced_accuracy: 0.5034 - mcc: 0.0066 - f1: 0.5410 - val_loss: 1.0828 - val_accuracy: 0.7401 - val_recall_with_logits_4: 1.0000 - val_precision_with_logits_4: 0.7401 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.6429
# Epoch 7/200
# 19/19 [==============================] - 46s 2s/step - loss: 1.0828 - accuracy: 0.5917 - recall_with_logits_4: 0.6652 - precision_with_logits_4: 0.7544 - balanced_accuracy: 0.4948 - mcc: 0.0097 - f1: 0.6013 - val_loss: 1.0809 - val_accuracy: 0.7385 - val_recall_with_logits_4: 1.0000 - val_precision_with_logits_4: 0.7385 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.6011
# Epoch 8/200
# 19/19 [==============================] - 45s 2s/step - loss: 1.0766 - accuracy: 0.6131 - recall_with_logits_4: 0.6878 - precision_with_logits_4: 0.7656 - balanced_accuracy: 0.5687 - mcc: 0.1237 - f1: 0.6295 - val_loss: 1.0782 - val_accuracy: 0.7385 - val_recall_with_logits_4: 1.0000 - val_precision_with_logits_4: 0.7385 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.5602
# Epoch 9/200
# 19/19 [==============================] - 47s 3s/step - loss: 1.0753 - accuracy: 0.5929 - recall_with_logits_4: 0.6615 - precision_with_logits_4: 0.7583 - balanced_accuracy: 0.5740 - mcc: 0.1498 - f1: 0.6227 - val_loss: 1.0763 - val_accuracy: 0.7368 - val_recall_with_logits_4: 1.0000 - val_precision_with_logits_4: 0.7368 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.7284
# Epoch 10/200
# 19/19 [==============================] - 46s 2s/step - loss: 1.0756 - accuracy: 0.5810 - recall_with_logits_4: 0.6363 - precision_with_logits_4: 0.7581 - balanced_accuracy: 0.4600 - mcc: 0.0680 - f1: 0.5895 - val_loss: 1.0720 - val_accuracy: 0.7401 - val_recall_with_logits_4: 1.0000 - val_precision_with_logits_4: 0.7401 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.5200
# Epoch 11/200
# 19/19 [==============================] - 47s 3s/step - loss: 1.0681 - accuracy: 0.5789 - recall_with_logits_4: 0.6362 - precision_with_logits_4: 0.7571 - balanced_accuracy: 0.6364 - mcc: 0.2279 - f1: 0.6639 - val_loss: 1.0702 - val_accuracy: 0.7385 - val_recall_with_logits_4: 1.0000 - val_precision_with_logits_4: 0.7385 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.6011
# Epoch 12/200
# 19/19 [==============================] - 48s 3s/step - loss: 1.0692 - accuracy: 0.5757 - recall_with_logits_4: 0.6262 - precision_with_logits_4: 0.7601 - balanced_accuracy: 0.5758 - mcc: 0.1498 - f1: 0.6273 - val_loss: 1.0668 - val_accuracy: 0.7401 - val_recall_with_logits_4: 1.0000 - val_precision_with_logits_4: 0.7401 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.7722
# Epoch 13/200
# 19/19 [==============================] - 47s 3s/step - loss: 1.0638 - accuracy: 0.5863 - recall_with_logits_4: 0.6294 - precision_with_logits_4: 0.7697 - balanced_accuracy: 0.4740 - mcc: 0.0477 - f1: 0.5434 - val_loss: 1.0641 - val_accuracy: 0.7401 - val_recall_with_logits_4: 1.0000 - val_precision_with_logits_4: 0.7401 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.5602
# Epoch 14/200
# 19/19 [==============================] - 45s 2s/step - loss: 1.0597 - accuracy: 0.5896 - recall_with_logits_4: 0.6307 - precision_with_logits_4: 0.7725 - balanced_accuracy: 0.5996 - mcc: 0.1659 - f1: 0.6574 - val_loss: 1.0615 - val_accuracy: 0.7401 - val_recall_with_logits_4: 1.0000 - val_precision_with_logits_4: 0.7401 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.5602
# Epoch 15/200
# 19/19 [==============================] - 46s 2s/step - loss: 1.0603 - accuracy: 0.5695 - recall_with_logits_4: 0.6057 - precision_with_logits_4: 0.7631 - balanced_accuracy: 0.5310 - mcc: 0.0591 - f1: 0.5878 - val_loss: 1.0614 - val_accuracy: 0.7352 - val_recall_with_logits_4: 1.0000 - val_precision_with_logits_4: 0.7352 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.7722
# Epoch 16/200
# 19/19 [==============================] - 46s 2s/step - loss: 1.0547 - accuracy: 0.5720 - recall_with_logits_4: 0.6031 - precision_with_logits_4: 0.7684 - balanced_accuracy: 0.5779 - mcc: 0.1307 - f1: 0.6346 - val_loss: 1.0572 - val_accuracy: 0.7385 - val_recall_with_logits_4: 1.0000 - val_precision_with_logits_4: 0.7385 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.5602
# Epoch 17/200
# 19/19 [==============================] - 47s 2s/step - loss: 1.0475 - accuracy: 0.5917 - recall_with_logits_4: 0.6281 - precision_with_logits_4: 0.7772 - balanced_accuracy: 0.5622 - mcc: 0.1151 - f1: 0.6169 - val_loss: 1.0557 - val_accuracy: 0.7352 - val_recall_with_logits_4: 0.9978 - val_precision_with_logits_4: 0.7364 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.6429
# Epoch 18/200
# 19/19 [==============================] - 46s 2s/step - loss: 1.0468 - accuracy: 0.5839 - recall_with_logits_4: 0.6223 - precision_with_logits_4: 0.7722 - balanced_accuracy: 0.5625 - mcc: 0.1050 - f1: 0.6420 - val_loss: 1.0523 - val_accuracy: 0.7319 - val_recall_with_logits_4: 0.9911 - val_precision_with_logits_4: 0.7368 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.5200
# Epoch 19/200
# 19/19 [==============================] - 46s 2s/step - loss: 1.0474 - accuracy: 0.5674 - recall_with_logits_4: 0.5996 - precision_with_logits_4: 0.7645 - balanced_accuracy: 0.5536 - mcc: 0.0900 - f1: 0.5909 - val_loss: 1.0499 - val_accuracy: 0.7319 - val_recall_with_logits_4: 0.9889 - val_precision_with_logits_4: 0.7375 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.6011
# Epoch 20/200
# 19/19 [==============================] - 45s 2s/step - loss: 1.0415 - accuracy: 0.5761 - recall_with_logits_4: 0.5986 - precision_with_logits_4: 0.7778 - balanced_accuracy: 0.5950 - mcc: 0.1645 - f1: 0.6730 - val_loss: 1.0488 - val_accuracy: 0.7122 - val_recall_with_logits_4: 0.9620 - val_precision_with_logits_4: 0.7313 - val_balanced_accuracy: 0.4583 - val_mcc: 0.1491 - val_f1: 0.6111
# Epoch 21/200
# 19/19 [==============================] - 45s 2s/step - loss: 1.
- val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.5182
# Epoch 28/200
# 19/19 [==============================] - 46s 2s/step - loss: 1.0187 - accuracy: 0.5995 - recall_with_logits_4: 0.6337 - precision_with_logits_4: 0.7835 - balanced_accuracy: 0.5239 - mcc: 0.0443 - f1: 0.5791 - val_loss: 1.0234 - val_accuracy: 0.5444 - val_recall_with_logits_4: 0.5578 - val_precision_with_logits_4: 0.7629 - val_balanced_accuracy: 0.5273 - val_mcc: 0.0510 - val_f1: 0.5159
# Epoch 29/200
# 19/19 [==============================] - 45s 2s/step - loss: 1.0157 - accuracy: 0.5946 - recall_with_logits_4: 0.6230 - precision_with_logits_4: 0.7852 - balanced_accuracy: 0.5518 - mcc: 0.1000 - f1: 0.5931 - val_loss: 1.0208 - val_accuracy: 0.5378 - val_recall_with_logits_4: 0.5212 - val_precision_with_logits_4: 0.7800 - val_balanced_accuracy: 0.6571 - val_mcc: 0.2604 - val_f1: 0.6575
# Epoch 30/200
# 19/19 [==============================] - 45s 2s/step - loss: 1.0094 - accuracy: 0.5933 - recall_with_logits_4: 0.6183 - precision_with_logits_4: 0.7881 - balanced_accuracy: 0.6210 - mcc: 0.2271 - f1: 0.6366 - val_loss: 1.0182 - val_accuracy: 0.5164 - val_recall_with_logits_4: 0.4911 - val_precision_with_logits_4: 0.7692 - val_balanced_accuracy: 0.5577 - val_mcc: 0.0917 - val_f1: 0.6370
# Epoch 31/200
# 19/19 [==============================] - 45s 2s/step - loss: 1.0069 - accuracy: 0.6229 - recall_with_logits_4: 0.6519 - precision_with_logits_4: 0.8027 - balanced_accuracy: 0.6182 - mcc: 0.2310 - f1: 0.6602 - val_loss: 1.0165 - val_accuracy: 0.5082 - val_recall_with_logits_4: 0.4676 - val_precision_with_logits_4: 0.7741 - val_balanced_accuracy: 0.6039 - val_mcc: 0.1974 - val_f1: 0.6039
# Epoch 32/200
# 19/19 [==============================] - 48s 3s/step - loss: 1.0059 - accuracy: 0.6155 - recall_with_logits_4: 0.6400 - precision_with_logits_4: 0.7997 - balanced_accuracy: 0.6479 - mcc: 0.2717 - f1: 0.6781 - val_loss: 1.0130 - val_accuracy: 0.4934 - val_recall_with_logits_4: 0.4576 - val_precision_with_logits_4: 0.7593 - val_balanced_accuracy: 0.6167 - val_mcc: 0.2437 - val_f1: 0.5539
# Epoch 33/200
# 19/19 [==============================] - 44s 2s/step - loss: 1.0066 - accuracy: 0.6024 - recall_with_logits_4: 0.6347 - precision_with_logits_4: 0.7857 - balanced_accuracy: 0.4898 - mcc: 0.0192 - f1: 0.5532 - val_loss: 1.0081 - val_accuracy: 0.5066 - val_recall_with_logits_4: 0.4723 - val_precision_with_logits_4: 0.7745 - val_balanced_accuracy: 0.4231 - val_mcc: 0.1240 - val_f1: 0.4281
# Epoch 34/200
# 19/19 [==============================] - 44s 2s/step - loss: 1.0034 - accuracy: 0.6007 - recall_with_logits_4: 0.6427 - precision_with_logits_4: 0.7783 - balanced_accuracy: 0.5207 - mcc: 0.0378 - f1: 0.5826 - val_loss: 1.0057 - val_accuracy: 0.4753 - val_recall_with_logits_4: 0.4343 - val_precision_with_logits_4: 0.7500 - val_balanced_accuracy: 0.6710 - val_mcc: 0.3307 - val_f1: 0.6309
# Epoch 35/200
200
# 19/19 [==============================] - 32s 2s/step - loss: 0.9046 - accuracy: 0.6328 - recall_with_logits_4: 0.6390 - precision_with_logits_4: 0.8272 - balanced_accuracy: 0.6386 - mcc: 0.2348 - f1: 0.6835 - val_loss: 0.9187 - val_accuracy: 0.5905 - val_recall_with_logits_4: 0.5902 - val_precision_with_logits_4: 0.8030 - val_balanced_accuracy: 0.5833 - val_mcc: 0.1443 - val_f1: 0.5917
# Epoch 67/200
# 19/19 [==============================] - 37s 2s/step - loss: 0.8982 - accuracy: 0.6600 - recall_with_logits_4: 0.6661 - precision_with_logits_4: 0.8422 - balanced_accuracy: 0.7354 - mcc: 0.4127 - f1: 0.7143 - val_loss: 0.9130 - val_accuracy: 0.5905 - val_recall_with_logits_4: 0.5844 - val_precision_with_logits_4: 0.8092 - val_balanced_accuracy: 0.4615 - val_mcc: 0.0605 - val_f1: 0.4937
# Epoch 68/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.9023 - accuracy: 0.6493 - recall_with_logits_4: 0.6596 - precision_with_logits_4: 0.8319 - balanced_accuracy: 0.6667 - mcc: 0.2981 - f1: 0.7045 - val_loss: 0.9110 - val_accuracy: 0.6069 - val_recall_with_logits_4: 0.6161 - val_precision_with_logits_4: 0.8047 - val_balanced_accuracy: 0.5417 - val_mcc: 0.0727 - val_f1: 0.5909
# Epoch 69/200
# 19/19 [==============================] - 28s 1s/step - loss: 0.8969 - accuracy: 0.6517 - recall_with_logits_4: 0.6593 - precision_with_logits_4: 0.8352 - balanced_accuracy: 0.7002 - mcc: 0.3493 - f1: 0.7154 - val_loss: 0.9089 - val_accuracy: 0.5559 - val_recall_with_logits_4: 0.5256 - val_precision_with_logits_4: 0.8055 - val_balanced_accuracy: 0.4425 - val_mcc: 0.0675 - val_f1: 0.6281
# Epoch 70/200
# 19/19 [==============================] - 27s 1s/step - loss: 0.8936 - accuracy: 0.6468 - recall_with_logits_4: 0.6529 - precision_with_logits_4: 0.8332 - balanced_accuracy: 0.6293 - mcc: 0.2194 - f1: 0.6392 - val_loss: 0.9077 - val_accuracy: 0.5576 - val_recall_with_logits_4: 0.5422 - val_precision_with_logits_4: 0.7948 - val_balanced_accuracy: 0.4583 - val_mcc: 0.0727 - val_f1: 0.4717
# Epoch 71/200
# 19/19 [==============================] - 27s 1s/step - loss: 0.8936 - accuracy: 0.6517 - recall_with_logits_4: 0.6563 - precision_with_logits_4: 0.8375 - balanced_accuracy: 0.5868 - mcc: 0.1557 - f1: 0.6151 - val_loss: 0.9054 - val_accuracy: 0.5724 - val_recall_with_logits_4: 0.5682 - val_precision_with_logits_4: 0.7913 - val_balanced_accuracy: 0.5192 - val_mcc: 0.0301 - val_f1: 0.5826
# Epoch 72/200
# 19/19 [==============================] - 27s 1s/step - loss: 0.8868 - accuracy: 0.6435 - recall_with_logits_4: 0.6463 - precision_with_logits_4: 0.8358 - balanced_accuracy: 0.6198 - mcc: 0.1971 - f1: 0.6882 - val_loss: 0.8995 - val_accuracy: 0.5773 - val_recall_with_logits_4: 0.5526 - val_precision_with_logits_4: 0.8125 - val_balanced_accuracy: 0.6250 - val_mcc: 0.1657 - val_f1: 0.6055
# Epoch 73/200
# 19/19 [==============================] - 28s 1s/step - loss: 0.8816 - accuracy: 0.6632 - recall_with_logits_4: 0.6609 - precision_with_logits_4: 0.8497 - balanced_accuracy: 0.6933 - mcc: 0.3317 - f1: 0.7177 - val_loss: 0.8996 - val_accuracy: 0.5954 - val_recall_with_logits_4: 0.5781 - val_precision_with_logits_4: 0.8196 - val_balanced_accuracy: 0.6955 - val_mcc: 0.3631 - val_f1: 0.6683
# Epoch 74/200
# 19/19 [==============================] - 29s 2s/step - loss: 0.8812 - accuracy: 0.6813 - recall_with_logits_4: 0.6798 - precision_with_logits_4: 0.8601 - balanced_accuracy: 0.6743 - mcc: 0.2934 - f1: 0.6987 - val_loss: 0.8925 - val_accuracy: 0.6069 - val_recall_with_logits_4: 0.6058 - val_precision_with_logits_4: 0.8144 - val_balanced_accuracy: 0.5048 - val_mcc: 0.0088 - val_f1: 0.5536
# Epoch 75/200
# 19/19 [==============================] - 28s 1s/step - loss: 0.8766 - accuracy: 0.6649 - recall_with_logits_4: 0.6622 - precision_with_logits_4: 0.8520 - balanced_accuracy: 0.6750 - mcc: 0.2833 - f1: 0.7043 - val_loss: 0.8949 - val_accuracy: 0.5921 - val_recall_with_logits_4: 0.5893 - val_precision_with_logits_4: 0.8049 - val_balanced_accuracy: 0.6159 - val_mcc: 0.2085 - val_f1: 0.6142
# Epoch 76/200
# 19/19 [==============================] - 29s 2s/step - loss: 0.8719 - accuracy: 0.6776 - recall_with_logits_4: 0.6818 - precision_with_logits_4: 0.8534 - balanced_accuracy: 0.6853 - mcc: 0.3442 - f1: 0.7215 - val_loss: 0.8942 - val_accuracy: 0.6102 - val_recall_with_logits_4: 0.6211 - val_precision_with_logits_4: 0.8029 - val_balanced_accuracy: 0.4928 - val_mcc: 0.0137 - val_f1: 0.5744
# Epoch 77/200
# 19/19 [==============================] - 29s 2s/step - loss: 0.8687 - accuracy: 0.6682 - recall_with_logits_4: 0.6663 - precision_with_logits_4: 0.8551 - balanced_accuracy: 0.7215 - mcc: 0.3959 - f1: 0.7342 - val_loss: 0.8901 - val_accuracy: 0.6003 - val_recall_with_logits_4: 0.5902 - val_precision_with_logits_4: 0.8179 - val_balanced_accuracy: 0.7662 - val_mcc: 0.5068 - val_f1: 0.7561
# Epoch 78/200
# 19/19 [==============================] - 29s 2s/step - loss: 0.8635 - accuracy: 0.6834 - recall_with_logits_4: 0.6752 - precision_with_logits_4: 0.8671 - balanced_accuracy: 0.6950 - mcc: 0.3561 - f1: 0.7089 - val_loss: 0.8877 - val_accuracy: 0.6053 - val_recall_with_logits_4: 0.6000 - val_precision_with_logits_4: 0.8182 - val_balanced_accuracy: 0.5179 - val_mcc: 0.0237 - val_f1: 0.6096
# Epoch 79/200
# 19/19 [==============================] - 28s 2s/step - loss: 0.8669 - accuracy: 0.6583 - recall_with_logits_4: 0.6652 - precision_with_logits_4: 0.8409 - balanced_accuracy: 0.6235 - mcc: 0.2088 - f1: 0.6547 - val_loss: 0.8848 - val_accuracy: 0.6020 - val_recall_with_logits_4: 0.6013 - val_precision_with_logits_4: 0.8108 - val_balanced_accuracy: 0.6715 - val_mcc: 0.3090 - val_f1: 0.6432
# Epoch 80/200
# 19/19 [==============================] - 28s 1s/step - loss: 0.8660 - accuracy: 0.6534 - recall_with_logits_4: 0.6580 - precision_with_logits_4: 0.8392 - balanced_accuracy: 0.6424 - mcc: 0.2695 - f1: 0.7036 - val_loss: 0.8829 - val_accuracy: 0.5905 - val_recall_with_logits_4: 0.5857 - val_precision_with_logits_4: 0.8067 - val_balanced_accuracy: 0.5250 - val_mcc: 0.0485 - val_f1: 0.5383
# Epoch 81/200
200
# 19/19 [==============================] - 33s 2s/step - loss: 0.4945 - accuracy: 0.9104 - recall_with_logits_4: 0.8961 - precision_with_logits_4: 0.9811 - balanced_accuracy: 0.8532 - mcc: 0.6577 - f1: 0.8719 - val_loss: 0.8380 - val_accuracy: 0.6908 - val_recall_with_logits_4: 0.8040 - val_precision_with_logits_4: 0.7831 - val_balanced_accuracy: 0.5943 - val_mcc: 0.1734 - val_f1: 0.7005
# Epoch 194/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.5014 - accuracy: 0.9050 - recall_with_logits_4: 0.8997 - precision_with_logits_4: 0.9701 - balanced_accuracy: 0.9574 - mcc: 0.8606 - f1: 0.9394 - val_loss: 0.8002 - val_accuracy: 0.7007 - val_recall_with_logits_4: 0.7790 - val_precision_with_logits_4: 0.8079 - val_balanced_accuracy: 0.5152 - val_mcc: 0.0303 - val_f1: 0.5625
# Epoch 195/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.4929 - accuracy: 0.9025 - recall_with_logits_4: 0.8933 - precision_with_logits_4: 0.9728 - balanced_accuracy: 0.8316 - mcc: 0.6362 - f1: 0.8393 - val_loss: 0.8400 - val_accuracy: 0.6924 - val_recall_with_logits_4: 0.7911 - val_precision_with_logits_4: 0.7929 - val_balanced_accuracy: 0.4864 - val_mcc: 0.0306 - val_f1: 0.5709
# Epoch 196/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.4940 - accuracy: 0.9034 - recall_with_logits_4: 0.8924 - precision_with_logits_4: 0.9752 - balanced_accuracy: 0.9471 - mcc: 0.8371 - f1: 0.9396 - val_loss: 0.8209 - val_accuracy: 0.6530 - val_recall_with_logits_4: 0.7299 - val_precision_with_logits_4: 0.7842 - val_balanced_accuracy: 0.5417 - val_mcc: 0.0727 - val_f1: 0.5909
# Epoch 197/200
# 19/19 [==============================] - 30s 2s/step - loss: 0.4900 - accuracy: 0.9013 - recall_with_logits_4: 0.8829 - precision_with_logits_4: 0.9814 - balanced_accuracy: 0.9367 - mcc: 0.7955 - f1: 0.9255 - val_loss: 0.8401 - val_accuracy: 0.6990 - val_recall_with_logits_4: 0.7902 - val_precision_with_logits_4: 0.7991 - val_balanced_accuracy: 0.5208 - val_mcc: 0.0380 - val_f1: 0.6123
# Epoch 198/200
# 19/19 [==============================] - 29s 2s/step - loss: 0.4835 - accuracy: 0.9091 - recall_with_logits_4: 0.9013 - precision_with_logits_4: 0.9742 - balanced_accuracy: 0.9271 - mcc: 0.8095 - f1: 0.9240 - val_loss: 0.8408 - val_accuracy: 0.6908 - val_recall_with_logits_4: 0.7902 - val_precision_with_logits_4: 0.7902 - val_balanced_accuracy: 0.6987 - val_mcc: 0.3266 - val_f1: 0.7452
# Epoch 199/200
# 19/19 [==============================] - 29s 2s/step - loss: 0.4784 - accuracy: 0.9169 - recall_with_logits_4: 0.9068 - precision_with_logits_4: 0.9796 - balanced_accuracy: 0.8893 - mcc: 0.6898 - f1: 0.8751 - val_loss: 0.8375 - val_accuracy: 0.6694 - val_recall_with_logits_4: 0.7545 - val_precision_with_logits_4: 0.7879 - val_balanced_accuracy: 0.9074 - val_mcc: 0.6383 - val_f1: 0.8618
# Epoch 200/200
# 19/19 [==============================] - 29s 2s/step - loss: 0.4761 - accuracy: 0.9206 - recall_with_logits_4: 0.9096 - precision_with_logits_4: 0.9820 - balanced_accuracy: 0.9105 - mcc: 0.7557 - f1: 0.9026 - val_loss: 0.8371 - val_accuracy: 0.6891 - val_recall_with_logits_4: 0.7840 - val_precision_with_logits_4: 0.7928 - val_balanced_accuracy: 0.6277 - val_mcc: 0.2431 - val_f1: 0.6341
# CPU times: total: 1h 34min 25s
# Wall time: 1h 51min 11s

# %%
# plot training curve
plt.subplots_adjust(left=0.1,
                    bottom=0.01,
                    right=1.7,
                    top=0.6,
                    wspace=0.4,
                    hspace=0.4)

# metric
plt.subplot(1, 4, 1)
plt.vlines(x=np.argmax(history.history['val_f1']), ymin=0,
           ymax=max(history.history['accuracy'] + history.history['val_accuracy']), color='red')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(1, 4, 2)
plt.vlines(x=np.argmax(history.history['val_f1']), ymin=0,
           ymax=max(history.history['mcc'] + history.history['val_mcc']), color='red')
plt.plot(history.history['mcc'])
plt.plot(history.history['val_mcc'])
plt.title('model MCC')
plt.ylabel('MCC')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(1, 4, 3)
plt.vlines(x=np.argmax(history.history['val_f1']), ymin=0,
           ymax=max(history.history['f1'] + history.history['val_f1']), color='red')
plt.plot(history.history['f1'])
plt.plot(history.history['val_f1'])
plt.title('model F1')
plt.ylabel('F1')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

# loss
plt.subplot(1, 4, 4)
plt.vlines(x=np.argmax(history.history['val_f1']), ymin=0,
           ymax=max(history.history['loss'] + history.history['val_loss']), color='red')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.show()

# %% [markdown]
# # Evaluation

# %%
# save latest model
current_model = tf.keras.models.clone_model(model)

# %%
# load best performing model
model.load_weights(checkpoint_path_f1)

# %%
# predict on validation set
plt.subplots_adjust(left=0.1,
                    bottom=0.01,
                    right=1.2,
                    top=0.6,
                    wspace=0.4,
                    hspace=0.4)

y_pred = model.predict(validation_batch_generator)
y_pred = tf.math.sigmoid(y_pred).numpy() # TODO: for logits

# for probs
plt.subplot(1, 2, 1)
plt.hist(y_pred.reshape(-1))
plt.title('P(y == 1)')
plt.vlines(x=0.5, ymin=0, ymax=500, color='red')

y_pred = np.where(y_pred > 0.5, 1, 0) # as labels
plt.subplot(1, 2, 2)
plt.hist(y_pred.reshape(-1))
plt.title('Labels')

plt.show()

# %%
# load test data
print(f'Test set: {len(validation_indices)}') # TODO: separate test-set

test_batch_generator = DataGenerator(data_path=path, indices_dataset=validation_indices, batch_size=1) # TODO: separate test-set
y_test = np.empty(0)
for batch_index in range(len(test_batch_generator)):
    _, y_test_batch = test_batch_generator.__getitem__(batch_index)
    y_test = np.append(y_test, y_test_batch)
# Out:
# Test set: 619

# %%
# classification metrics
# predict
y_test_pred = model.predict(test_batch_generator)
y_test_pred = tf.math.sigmoid(y_test_pred).numpy() # TODO: for logits
y_test_pred = np.round(y_test_pred)

# evaluate
accuracy = accuracy_score(y_pred=y_test_pred, y_true=y_test)
balanced_accuracy = balanced_accuracy_score(y_pred=y_test_pred, y_true=y_test)
f1_weighted = f1_score(y_pred=y_test_pred, y_true=y_test, average='weighted')
recall_weighted = recall_score(y_pred=y_test_pred, y_true=y_test, average='weighted')
precision_weighted = precision_score(y_pred=y_test_pred, y_true=y_test, average='weighted')
confusion = confusion_matrix(y_pred=y_test_pred, y_true=y_test)
ConfusionMatrixDisplay(confusion_matrix=confusion, display_labels=[False, True]).plot(cmap=plt.cm.Blues)
plt.title('Physical fatigue')

print(f'accuracy: {accuracy}\n'
      f'balanced accuracy: {balanced_accuracy}\n'
      f'f1 (weighted): {f1_weighted}\n'
      f'recall (weighted): {recall_weighted}\n'
      f'precision (weighted): {precision_weighted}')
# Out:
# accuracy: 0.5654281098546042
# balanced accuracy: 0.5602493448955885
# f1 (weighted): 0.5914303750130168
# recall (weighted): 0.5654281098546042
# precision (weighted): 0.6586530535561816

# %% [markdown]
# # Save data

# %%
# save history
with open('./temp/history_acc','w') as dat:
    dat.write(str(history.history['accuracy']))

with open('./temp/history_val_acc','w') as dat:
    dat.write(str(history.history['val_accuracy']))

with open('./temp/history_loss','w') as dat:
    dat.write(str(history.history['loss']))

with open('./temp/history_val_loss','w') as dat:
    dat.write(str(history.history['val_loss']))

with open('./temp/history_mcc','w') as dat:
    dat.write(str(history.history['mcc']))

with open('./temp/history_val_mcc','w') as dat:
    dat.write(str(history.history['val_mcc']))

with open('./temp/history_f1','w') as dat:
    dat.write(str(history.history['f1']))

with open('./temp/history_val_f1','w') as dat:
    dat.write(str(history.history['val_f1']))

# %%
# save latest model
model.save('./temp/checkpoint_latest')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) conv1-1_input with unsupported characters which will be renamed to conv1_1_input in the SavedModel.
# INFO:tensorflow:Assets written to: ./temp/checkpoint_latest\assets
# INFO:tensorflow:Assets written to: ./temp/checkpoint_latest\assets

# %% [markdown]
# # Continue training

# %%
# load latest
model = tf.keras.models.clone_model(model)
model.compile(optimizer=Adam(learning_rate=1e-5), loss=weighted_cross_entropy(sample_weight), metrics=[accuracy_with_logits(),
                                                                                                       recall_with_logits(),
                                                                                                       precision_with_logits(),
                                                                                                       BalancedAccuracy(),
                                                                                                       MCC(),
                                                                                                       F1()])

# %%
# %%time
# save best performing model
checkpoint_path_mcc_2 = './temp/checkpoint_model_mcc_2'
model_checkpoint_callback_mcc_2 = ModelCheckpoint(filepath=checkpoint_path_mcc_2,
                                                save_weights_only=True,
                                                monitor='val_mcc',
                                                save_best_only=True)
checkpoint_path_f1_2 = './temp/checkpoint_model_f1_2'
model_checkpoint_callback_f1_2 = ModelCheckpoint(filepath=checkpoint_path_f1_2,
                                               save_weights_only=True,
                                               monitor='val_f1',
                                               save_best_only=True)

# train
history2 = model.fit_generator(generator=training_batch_generator,
                              validation_data=validation_batch_generator,
                              epochs=200,
                              callbacks=[model_checkpoint_callback_mcc_2, model_checkpoint_callback_f1_2])
# Out:
# Epoch 1/200
# 19/19 [==============================] - 39s 2s/step - loss: 1.1101 - accuracy: 0.3906 - recall_with_logits_5: 0.2734 - precision_with_logits_5: 0.7414 - balanced_accuracy: 0.5221 - mcc: 0.0392 - f1: 0.4418 - val_loss: 1.0967 - val_accuracy: 0.2664 - val_recall_with_logits_5: 0.0000e+00 - val_precision_with_logits_5: 0.0000e+00 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.0592
# Epoch 2/200
# 19/19 [==============================] - 29s 2s/step - loss: 1.1060 - accuracy: 0.3964 - recall_with_logits_5: 0.2875 - precision_with_logits_5: 0.7379 - balanced_accuracy: 0.5019 - mcc: 0.0036 - f1: 0.4144 - val_loss: 1.0920 - val_accuracy: 0.2615 - val_recall_with_logits_5: 0.0000e+00 - val_precision_with_logits_5: 0.0000e+00 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.0422
# Epoch 3/200
# 19/19 [==============================] - 31s 2s/step - loss: 1.1015 - accuracy: 0.4104 - recall_with_logits_5: 0.3158 - precision_with_logits_5: 0.7390 - balanced_accuracy: 0.5417 - mcc: 0.0895 - f1: 0.3982 - val_loss: 1.0888 - val_accuracy: 0.2599 - val_recall_with_logits_5: 0.0000e+00 - val_precision_with_logits_5: 0.0000e+00 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.1000
# Epoch 4/200
# 19/19 [==============================] - 31s 2s/step - loss: 1.0969 - accuracy: 0.4412 - recall_with_logits_5: 0.3572 - precision_with_logits_5: 0.7609 - balanced_accuracy: 0.4895 - mcc: 0.0202 - f1: 0.4628 - val_loss: 1.0864 - val_accuracy: 0.2599 - val_recall_with_logits_5: 0.0000e+00 - val_precision_with_logits_5: 0.0000e+00 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.0422
# Epoch 5/200
# 19/19 [==============================] - 32s 2s/step - loss: 1.0979 - accuracy: 0.4178 - recall_with_logits_5: 0.3411 - precision_with_logits_5: 0.7275 - balanced_accuracy: 0.5374 - mcc: 0.0702 - f1: 0.4838 - val_loss: 1.0839 - val_accuracy: 0.2599 - val_recall_with_logits_5: 0.0000e+00 - val_precision_with_logits_5: 0.0000e+00 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.1759
# Epoch 6/200
# 19/19 [==============================] - 32s 2s/step - loss: 1.0939 - accuracy: 0.4371 - recall_with_logits_5: 0.3685 - precision_with_logits_5: 0.7419 - balanced_accuracy: 0.4659 - mcc: 0.0638 - f1: 0.4550 - val_loss: 1.0829 - val_accuracy: 0.2632 - val_recall_with_logits_5: 0.0000e+00 - val_precision_with_logits_5: 0.0000e+00 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.0592
# Epoch 7/200
# 19/19 [==============================] - 32s 2s/step - loss: 1.0898 - accuracy: 0.4486 - recall_with_logits_5: 0.3826 - precision_with_logits_5: 0.7505 - balanced_accuracy: 0.4763 - mcc: 0.0439 - f1: 0.4644 - val_loss: 1.0797 - val_accuracy: 0.2615 - val_recall_with_logits_5: 0.0000e+00 - val_precision_with_logits_5: 0.0000e+00 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0
200
# 19/19 [==============================] - 28s 1s/step - loss: 1.0559 - accuracy: 0.4979 - recall_with_logits_5: 0.4730 - precision_with_logits_5: 0.7553 - balanced_accuracy: 0.5268 - mcc: 0.0459 - f1: 0.5499 - val_loss: 1.0504 - val_accuracy: 0.3158 - val_recall_with_logits_5: 0.1044 - val_precision_with_logits_5: 0.7833 - val_balanced_accuracy: 0.5185 - val_mcc: 0.0773 - val_f1: 0.1037
# Epoch 20/200
# 19/19 [==============================] - 28s 1s/step - loss: 1.0500 - accuracy: 0.5021 - recall_with_logits_5: 0.4781 - precision_with_logits_5: 0.7624 - balanced_accuracy: 0.4824 - mcc: 0.0278 - f1: 0.4999 - val_loss: 1.0490 - val_accuracy: 0.3372 - val_recall_with_logits_5: 0.1581 - val_precision_with_logits_5: 0.7396 - val_balanced_accuracy: 0.5435 - val_mcc: 0.1615 - val_f1: 0.2448
# Epoch 21/200
# 19/19 [==============================] - 28s 1s/step - loss: 1.0509 - accuracy: 0.5029 - recall_with_logits_5: 0.4822 - precision_with_logits_5: 0.7572 - balanced_accuracy: 0.5494 - mcc: 0.0936 - f1: 0.5433 - val_loss: 1.0468 - val_accuracy: 0.3684 - val_recall_with_logits_5: 0.2361 - val_precision_with_logits_5: 0.7211 - val_balanced_accuracy: 0.5931 - val_mcc: 0.2343 - val_f1: 0.4875
# Epoch 22/200
# 19/19 [==============================] - 28s 1s/step - loss: 1.0481 - accuracy: 0.5029 - recall_with_logits_5: 0.4755 - precision_with_logits_5: 0.7618 - balanced_accuracy: 0.5466 - mcc: 0.0826 - f1: 0.5804 - val_loss: 1.0444 - val_accuracy: 0.4095 - val_recall_with_logits_5: 0.3185 - val_precision_with_logits_5: 0.7296 - val_balanced_accuracy: 0.3188 - val_mcc: 0.3317 - val_f1: 0.3398
# Epoch 23/200
# 19/19 [==============================] - 29s 2s/step - loss: 1.0469 - accuracy: 0.4910 - recall_with_logits_5: 0.4603 - precision_with_logits_5: 0.7571 - balanced_accuracy: 0.4894 - mcc: 0.0173 - f1: 0.4841 - val_loss: 1.0427 - val_accuracy: 0.3964 - val_recall_with_logits_5: 0.3274 - val_precision_with_logits_5: 0.6934 - val_balanced_accuracy: 0.4543 - val_mcc: 0.0756 - val_f1: 0.5144
# Epoch 24/200
# 19/19 [==============================] - 29s 2s/step - loss: 1.0373 - accuracy: 0.5177 - recall_with_logits_5: 0.4897 - precision_with_logits_5: 0.7755 - balanced_accuracy: 0.4788 - mcc: 0.0356 - f1: 0.5183 - val_loss: 1.0394 - val_accuracy: 0.4112 - val_recall_with_logits_5: 0.3311 - val_precision_with_logits_5: 0.7233 - val_balanced_accuracy: 0.5371 - val_mcc: 0.0647 - val_f1: 0.4687
# Epoch 25/200
# 19/19 [==============================] - 29s 2s/step - loss: 1.0373 - accuracy: 0.5218 - recall_with_logits_5: 0.5022 - precision_with_logits_5: 0.7728 - balanced_accuracy: 0.5521 - mcc: 0.0965 - f1: 0.5173 - val_loss: 1.0360 - val_accuracy: 0.4243 - val_recall_with_logits_5: 0.3659 - val_precision_with_logits_5: 0.7205 - val_balanced_accuracy: 0.5591 - val_mcc: 0.1218 - val_f1: 0.4620
# Epoch 26/200
# 19/19 [==============================] - 29s 2s/step - loss: 1.0378 - accuracy: 0.5070 - recall_with_logits_5: 0.4839 - precision_with_logits_5: 0.7642 - balanced_accuracy: 0.6080 - mcc: 0.1780 - f1: 0.5700 - val_loss: 1.0374 - val_accuracy: 0.4227 - val_recall_with_logits_5: 0.3408 - val_precision_with_logits_5: 0.7273 - val_balanced_accuracy: 0.3393 - val_mcc: 0.2571 - val_f1: 0.2672
# Epoch 27/200
# 19/19 [==============================] - 28s 1s/step - loss: 1.
200
# 19/19 [==============================] - 31s 2s/step - loss: 1.0167 - accuracy: 0.5222 - recall_with_logits_5: 0.4994 - precision_with_logits_5: 0.7733 - balanced_accuracy: 0.4854 - mcc: 0.0268 - f1: 0.4900 - val_loss: 1.0142 - val_accuracy: 0.4770 - val_recall_with_logits_5: 0.4116 - val_precision_with_logits_5: 0.7699 - val_balanced_accuracy: 0.5371 - val_mcc: 0.0647 - val_f1: 0.4687
# Epoch 35/200
# 19/19 [==============================] - 31s 2s/step - loss: 1.0164 - accuracy: 0.5119 - recall_with_logits_5: 0.4992 - precision_with_logits_5: 0.7584 - balanced_accuracy: 0.5205 - mcc: 0.0382 - f1: 0.5393 - val_loss: 1.0118 - val_accuracy: 0.4967 - val_recall_with_logits_5: 0.4308 - val_precision_with_logits_5: 0.7910 - val_balanced_accuracy: 0.4375 - val_mcc: 0.1085 - val_f1: 0.5042
# Epoch 36/200
# 19/19 [==============================] - 31s 2s/step - loss: 1.0086 - accuracy: 0.5387 - recall_with_logits_5: 0.5230 - precision_with_logits_5: 0.7817 - balanced_accuracy: 0.5167 - mcc: 0.0266 - f1: 0.5867 - val_loss: 1.0088 - val_accuracy: 0.4819 - val_recall_with_logits_5: 0.4120 - val_precision_with_logits_5: 0.7839 - val_balanced_accuracy: 0.5563 - val_mcc: 0.1078 - val_f1: 0.5409
# Epoch 37/200
# 19/19 [==============================] - 31s 2s/step - loss: 1.0101 - accuracy: 0.5169 - recall_with_logits_5: 0.5050 - precision_with_logits_5: 0.7636 - balanced_accuracy: 0.5537 - mcc: 0.0911 - f1: 0.5815 - val_loss: 1.0062 - val_accuracy: 0.4836 - val_recall_with_logits_5: 0.4165 - val_precision_with_logits_5: 0.7824 - val_balanced_accuracy: 0.4545 - val_mcc: 0.0849 - val_f1: 0.4554
# Epoch 38/200
# 19/19 [==============================] - 31s 2s/step - loss: 1.0079 - accuracy: 0.5041 - recall_with_logits_5: 0.4884 - precision_with_logits_5: 0.7569 - balanced_accuracy: 0.5134 - mcc: 0.0239 - f1: 0.5265 - val_loss: 1.0054 - val_accuracy: 0.4770 - val_recall_with_logits_5: 0.4094 - val_precision_with_logits_5: 0.7722 - val_balanced_accuracy: 0.6171 - val_mcc: 0.1941 - val_f1: 0.5990
# Epoch 39/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9982 - accuracy: 0.5477 - recall_with_logits_5: 0.5341 - precision_with_logits_5: 0.7874 - balanced_accuracy: 0.5122 - mcc: 0.0218 - f1: 0.5035 - val_loss: 1.0018 - val_accuracy: 0.5049 - val_recall_with_logits_5: 0.4598 - val_precision_with_logits_5: 0.7774 - val_balanced_accuracy: 0.5208 - val_mcc: 0.0362 - val_f1: 0.5626
# Epoch 40/200
# 19/19 [==============================] - 31s 2s/step - loss: 1.0013 - accuracy: 0.5362 - recall_with_logits_5: 0.5238 - precision_with_logits_5: 0.7784 - balanced_accuracy: 0.5732 - mcc: 0.1264 - f1: 0.6148 - val_loss: 1.0000 - val_accuracy: 0.5066 - val_recall_with_logits_5: 0.4844 - val_precision_with_logits_5: 0.7587 - val_balanced_accuracy: 0.6429 - val_mcc: 0.1890 - val_f1: 0.6341
# Epoch 41/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9958 - accuracy: 0.5312 - recall_with_logits_5: 0.5211 - precision_with_logits_5: 0.7722 - balanced_accuracy: 0.6348 - mcc: 0.2258 - f1: 0.6190 - val_loss: 0.9981 - val_accuracy: 0.4951 - val_recall_with_logits_5: 0.4576 - val_precision_with_logits_5: 0.7621 - val_balanced_accuracy: 0.6618 - val_mcc: 0.3064 - val_f1: 0.5728
# Epoch 42/200
# 19/19 [==============================] - 30s 2s/step - loss: 1.0003 - accuracy: 0.5259 - recall_with_logits_5: 0.5188 - precision_with_logits_5: 0.7666 - balanced_accuracy: 0.5712 - mcc: 0.1338 - f1: 0.5679 - val_loss: 0.9954 - val_accuracy: 0.4951 - val_recall_with_logits_5: 0.4722 - val_precision_with_logits_5: 0.7518 - val_balanced_accuracy: 0.5625 - val_mcc: 0.1085 - val_f1: 0.5615
# Epoch 43/200
# 19/19 [==============================] - 28s 2s/step - loss: 0.9957 - accuracy: 0.5247 - recall_with_logits_5: 0.5158 - precision_with_logits_5: 0.7650 - balanced_accuracy: 0.5173 - mcc: 0.0321 - f1: 0.5560 - val_loss: 0.9914 - val_accuracy: 0.5362 - val_recall_with_logits_5: 0.4989 - val_precision_with_logits_5: 0.7972 - val_balanced_accuracy: 0.5455 - val_mcc: 0.0849 - val_f1: 0.5771
# Epoch 44/200
# 19/19 [==============================] - 29s 2s/step - loss: 0.9899 - accuracy: 0.5333 - recall_with_logits_5: 0.5200 - precision_with_logits_5: 0.7755 - balanced_accuracy: 0.5257 - mcc: 0.0426 - f1: 0.5417 - val_loss: 0.9887 - val_accuracy: 0.5099 - val_recall_with_logits_5: 0.4656 - val_precision_with_logits_5: 0.7865 - val_balanced_accuracy: 0.5357 - val_mcc: 0.0476 - val_f1: 0.6365
# Epoch 45/200
# 19/19 [==============================] - 28s 2s/step - loss: 0.9915 - accuracy: 0.5127 - recall_with_logits_5: 0.5103 - precision_with_logits_5: 0.7529 - balanced_accuracy: 0.5885 - mcc: 0.1608 - f1: 0.6051 - val_loss: 0.9879 - val_accuracy: 0.5066 - val_recall_with_logits_5: 0.4699 - val_precision_with_logits_5: 0.7729 - val_balanced_accuracy: 0.5980 - val_mcc: 0.1972 - val_f1: 0.5926
# Epoch 46/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9842 - accuracy: 0.5317 - recall_with_logits_5: 0.5133 - precision_with_logits_5: 0.7776 - balanced_accuracy: 0.4884 - mcc: 0.0196 - f1: 0.5382 - val_loss: 0.9854 - val_accuracy: 0.5016 - val_recall_with_logits_5: 0.4799 - val_precision_with_logits_5: 0.7544 - val_balanced_accuracy: 0.6042 - val_mcc: 0.1808 - val_f1: 0.6209
# Epoch 47/200
# 19/19 [==============================] - 30s 2s/step - loss: 0.9794 - accuracy: 0.5489 - recall_with_logits_5: 0.5281 - precision_with_logits_5: 0.7930 - balanced_accuracy: 0.5860 - mcc: 0.1572 - f1: 0.5963 - val_loss: 0.9856 - val_accuracy: 0.5016 - val_recall_with_logits_5: 0.4722 - val_precision_with_logits_5: 0.7626 - val_balanced_accuracy: 0.5169 - val_mcc: 0.0305 - val_f1: 0.5243
# Epoch 48/200
# 19/19 [==============================] - 30s 2s/step - loss: 0.9787 - accuracy: 0.5436 - recall_with_logits_5: 0.5348 - precision_with_logits_5: 0.7824 - balanced_accuracy: 0.5769 - mcc: 0.1303 - f1: 0.5809 - val_loss: 0.9835 - val_accuracy: 0.5263 - val_recall_with_logits_5: 0.5123 - val_precision_with_logits_5: 0.7659 - val_balanced_accuracy: 0.4654 - val_mcc: 0.0658 - val_f1: 0.4820
# Epoch 49/200
# 19/19 [==============================] - 30s 2s/step - loss: 0.9788 - accuracy: 0.5391 - recall_with_logits_5: 0.5325 - precision_with_logits_5: 0.7746 - balanced_accuracy: 0.4565 - mcc: 0.0738 - f1: 0.5091 - val_loss: 0.9837 - val_accuracy: 0.5132 - val_recall_with_logits_5: 0.4922 - val_precision_with_logits_5: 0.7612 - val_balanced_accuracy: 0.4062 - val_mcc: 0.1909 - val_f1: 0.4010
# Epoch 50/200
# 19/19 [==============================] - 30s 2s/step - loss: 0.9779 - accuracy: 0.5354 - recall_with_logits_5: 0.5289 - precision_with_logits_5: 0.7715 - balanced_accuracy: 0.4323 - mcc: 0.1174 - f1: 0.4970 - val_loss: 0.9817 - val_accuracy: 0.4967 - val_recall_with_logits_5: 0.4855 - val_precision_with_logits_5: 0.7406 - val_balanced_accuracy: 0.3125 - val_mcc: 0.3254 - val_f1: 0.3862
# Epoch 51/200
# 19/19 [==============================] - 30s 2s/step - loss: 0.9751 - accuracy: 0.5551 - recall_with_logits_5: 0.5500 - precision_with_logits_5: 0.7845 - balanced_accuracy: 0.5420 - mcc: 0.0762 - f1: 0.5530 - val_loss: 0.9782 - val_accuracy: 0.5148 - val_recall_with_logits_5: 0.4966 - val_precision_with_logits_5: 0.7603 - val_balanced_accuracy: 0.4598 - val_mcc: 0.0478 - val_f1: 0.6536
# Epoch 52/200
# 19/19 [==============================] - 33s 2s/step - loss: 0.9729 - accuracy: 0.5358 - recall_with_logits_5: 0.5228 - precision_with_logits_5: 0.7754 - balanced_accuracy: 0.5417 - mcc: 0.0723 - f1: 0.5771 - val_loss: 0.9729 - val_accuracy: 0.5280 - val_recall_with_logits_5: 0.5166 - val_precision_with_logits_5: 0.7715 - val_balanced_accuracy: 0.5407 - val_mcc: 0.0593 - val_f1: 0.5649
# Epoch 53/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.9727 - accuracy: 0.5341 - recall_with_logits_5: 0.5328 - precision_with_logits_5: 0.7666 - balanced_accuracy: 0.5132 - mcc: 0.0240 - f1: 0.5289 - val_loss: 0.9720 - val_accuracy: 0.5428 - val_recall_with_logits_5: 0.5367 - val_precision_with_logits_5: 0.7749 - val_balanced_accuracy: 0.4829 - val_mcc: 0.0306 - val_f1: 0.6166
# Epoch 54/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9689 - accuracy: 0.5415 - recall_with_logits_5: 0.5363 - precision_with_logits_5: 0.7761 - balanced_accuracy: 0.5876 - mcc: 0.1608 - f1: 0.5571 - val_loss: 0.9687 - val_accuracy: 0.5033 - val_recall_with_logits_5: 0.4922 - val_precision_with_logits_5: 0.7525 - val_balanced_accuracy: 0.5500 - val_mcc: 0.0929 - val_f1: 0.5477
# Epoch 55/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9633 - accuracy: 0.5584 - recall_with_logits_5: 0.5497 - precision_with_logits_5: 0.7901 - balanced_accuracy: 0.5783 - mcc: 0.1356 - f1: 0.6218 - val_loss: 0.9680 - val_accuracy: 0.5395 - val_recall_with_logits_5: 0.5390 - val_precision_with_logits_5: 0.7683 - val_balanced_accuracy: 0.5962 - val_mcc: 0.1580 - val_f1: 0.6885
# Epoch 56/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9625 - accuracy: 0.5387 - recall_with_logits_5: 0.5189 - precision_with_logits_5: 0.7857 - balanced_accuracy: 0.4787 - mcc: 0.0377 - f1: 0.4986 - val_loss: 0.9651 - val_accuracy: 0.5378 - val_recall_with_logits_5: 0.5301 - val_precision_with_logits_5: 0.7727 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.5541
# Epoch 57/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9563 - accuracy: 0.5662 - recall_with_logits_5: 0.5546 - precision_with_logits_5: 0.7995 - balanced_accuracy: 0.6738 - mcc: 0.2798 - f1: 0.6544 - val_loss: 0.9627 - val_accuracy: 0.5214 - val_recall_with_logits_5: 0.5100 - val_precision_with_logits_5: 0.7633 - val_balanced_accuracy: 0.5821 - val_mcc: 0.1489 - val_f1: 0.6131
# Epoch 58/200
# 19/19 [==============================] - 30s 2s/step - loss: 0.9560 - accuracy: 0.5506 - recall_with_logits_5: 0.5395 - precision_with_logits_5: 0.7854 - balanced_accuracy: 0.4974 - mcc: 0.0049 - f1: 0.5278 - val_loss: 0.9621 - val_accuracy: 0.5345 - val_recall_with_logits_5: 0.5212 - val_precision_with_logits_5: 0.7748 - val_balanced_accuracy: 0.4792 - val_mcc: 0.0367 - val_f1: 0.5598
# Epoch 59/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9570 - accuracy: 0.5448 - recall_with_logits_5: 0.5361 - precision_with_logits_5: 0.7801 - balanced_accuracy: 0.4880 - mcc: 0.0218 - f1: 0.5232 - val_loss: 0.9614 - val_accuracy: 0.5345 - val_recall_with_logits_5: 0.5378 - val_precision_with_logits_5: 0.7634 - val_balanced_accuracy: 0.5115 - val_mcc: 0.0145 - val_f1: 0.7252
# Epoch 60/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9526 - accuracy: 0.5440 - recall_with_logits_5: 0.5424 - precision_with_logits_5: 0.7758 - balanced_accuracy: 0.5885 - mcc: 0.1549 - f1: 0.6271 - val_loss: 0.9587 - val_accuracy: 0.5082 - val_recall_with_logits_5: 0.4967 - val_precision_with_logits_5: 0.7534 - val_balanced_accuracy: 0.5266 - val_mcc: 0.0486 - val_f1: 0.5814
# Epoch 61/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9483 - accuracy: 0.5617 - recall_with_logits_5: 0.5529 - precision_with_logits_5: 0.7940 - balanced_accuracy: 0.5841 - mcc: 0.1448 - f1: 0.6153 - val_loss: 0.9548 - val_accuracy: 0.5148 - val_recall_with_logits_5: 0.4989 - val_precision_with_logits_5: 0.7619 - val_balanced_accuracy: 0.4831 - val_mcc: 0.0305 - val_f1: 0.5250
# Epoch 62/200
# 19/19 [==============================] - 30s 2s/step - loss: 0.9478 - accuracy: 0.5559 - recall_with_logits_5: 0.5467 - precision_with_logits_5: 0.7885 - balanced_accuracy: 0.5839 - mcc: 0.1538 - f1: 0.6034 - val_loss: 0.9523 - val_accuracy: 0.5280 - val_recall_with_logits_5: 0.5089 - val_precision_with_logits_5: 0.7729 - val_balanced_accuracy: 0.4500 - val_mcc: 0.0976 - val_f1: 0.4441
# Epoch 63/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9449 - accuracy: 0.5469 - recall_with_logits_5: 0.5305 - precision_with_logits_5: 0.7888 - balanced_accuracy: 0.6679 - mcc: 0.2779 - f1: 0.6351 - val_loss: 0.9510 - val_accuracy: 0.5197 - val_recall_with_logits_5: 0.5078 - val_precision_with_logits_5: 0.7625 - val_balanced_accuracy: 0.4396 - val_mcc: 0.1088 - val_f1: 0.4648
# Epoch 64/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9400 - accuracy: 0.5629 - recall_with_logits_5: 0.5533 - precision_with_logits_5: 0.7936 - balanced_accuracy: 0.5875 - mcc: 0.1419 - f1: 0.6330 - val_loss: 0.9479 - val_accuracy: 0.5164 - val_recall_with_logits_5: 0.5200 - val_precision_with_logits_5: 0.7500 - val_balanced_accuracy: 0.4792 - val_mcc: 0.0362 - val_f1: 0.5031
# Epoch 65/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9396 - accuracy: 0.5547 - recall_with_logits_5: 0.5388 - precision_with_logits_5: 0.7956 - balanced_accuracy: 0.5810 - mcc: 0.1360 - f1: 0.6124 - val_loss: 0.9452 - val_accuracy: 0.5428 - val_recall_with_logits_5: 0.5446 - val_precision_with_logits_5: 0.7673 - val_balanced_accuracy: 0.5143 - val_mcc: 0.0240 - val_f1: 0.5983
# Epoch 66/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9377 - accuracy: 0.5576 - recall_with_logits_5: 0.5491 - precision_with_logits_5: 0.7893 - balanced_accuracy: 0.5273 - mcc: 0.0510 - f1: 0.5159 - val_loss: 0.9442 - val_accuracy: 0.5510 - val_recall_with_logits_5: 0.5491 - val_precision_with_logits_5: 0.7760 - val_balanced_accuracy: 0.5833 - val_mcc: 0.1491 - val_f1: 0.6455
# Epoch 67/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9351 - accuracy: 0.5695 - recall_with_logits_5: 0.5701 - precision_with_logits_5: 0.7915 - balanced_accuracy: 0.5912 - mcc: 0.1640 - f1: 0.5918 - val_loss: 0.9395 - val_accuracy: 0.5493 - val_recall_with_logits_5: 0.5578 - val_precision_with_logits_5: 0.7699 - val_balanced_accuracy: 0.5457 - val_mcc: 0.0756 - val_f1: 0.5715
# Epoch 68/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9337 - accuracy: 0.5551 - recall_with_logits_5: 0.5475 - precision_with_logits_5: 0.7869 - balanced_accuracy: 0.5857 - mcc: 0.1455 - f1: 0.6103 - val_loss: 0.9361 - val_accuracy: 0.5296 - val_recall_with_logits_5: 0.5277 - val_precision_with_logits_5: 0.7653 - val_balanced_accuracy: 0.6593 - val_mcc: 0.2318 - val_f1: 0.6193
# Epoch 69/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9295 - accuracy: 0.5785 - recall_with_logits_5: 0.5721 - precision_with_logits_5: 0.8006 - balanced_accuracy: 0.5906 - mcc: 0.1636 - f1: 0.6137 - val_loss: 0.9334 - val_accuracy: 0.5395 - val_recall_with_logits_5: 0.5277 - val_precision_with_logits_5: 0.7803 - val_balanced_accuracy: 0.7148 - val_mcc: 0.3145 - val_f1: 0.7033
# Epoch 70/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9293 - accuracy: 0.5600 - recall_with_logits_5: 0.5552 - precision_with_logits_5: 0.7880 - balanced_accuracy: 0.4971 - mcc: 0.0047 - f1: 0.5576 - val_loss: 0.9372 - val_accuracy: 0.5280 - val_recall_with_logits_5: 0.5235 - val_precision_with_logits_5: 0.7597 - val_balanced_accuracy: 0.5507 - val_mcc: 0.0929 - val_f1: 0.5198
# Epoch 71/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.9261 - accuracy: 0.5580 - recall_with_logits_5: 0.5509 - precision_with_logits_5: 0.7878 - balanced_accuracy: 0.6308 - mcc: 0.2312 - f1: 0.6322 - val_loss: 0.9348 - val_accuracy: 0.5263 - val_recall_with_logits_5: 0.5101 - val_precision_with_logits_5: 0.7677 - val_balanced_accuracy: 0.3333 - val_mcc: 0.2981 - val_f1: 0.4682
# Epoch 72/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.9247 - accuracy: 0.5629 - recall_with_logits_5: 0.5596 - precision_with_logits_5: 0.7895 - balanced_accuracy: 0.6146 - mcc: 0.1993 - f1: 0.6352 - val_loss: 0.9310 - val_accuracy: 0.5378 - val_recall_with_logits_5: 0.5234 - val_precision_with_logits_5: 0.7781 - val_balanced_accuracy: 0.5852 - val_mcc: 0.1302 - val_f1: 0.4922
# Epoch 73/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.9201 - accuracy: 0.5732 - recall_with_logits_5: 0.5655 - precision_with_logits_5: 0.7998 - balanced_accuracy: 0.6250 - mcc: 0.2169 - f1: 0.6355 - val_loss: 0.9296 - val_accuracy: 0.5033 - val_recall_with_logits_5: 0.4844 - val_precision_with_logits_5: 0.7569 - val_balanced_accuracy: 0.4833 - val_mcc: 0.0348 - val_f1: 0.4265
# Epoch 74/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.9157 - accuracy: 0.5765 - recall_with_logits_5: 0.5573 - precision_with_logits_5: 0.8107 - balanced_accuracy: 0.5119 - mcc: 0.0211 - f1: 0.5581 - val_loss: 0.9264 - val_accuracy: 0.5263 - val_recall_with_logits_5: 0.5134 - val_precision_with_logits_5: 0.7667 - val_balanced_accuracy: 0.5507 - val_mcc: 0.0929 - val_f1: 0.5198
# Epoch 75/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.9158 - accuracy: 0.5810 - recall_with_logits_5: 0.5715 - precision_with_logits_5: 0.8049 - balanced_accuracy: 0.7171 - mcc: 0.3909 - f1: 0.6577 - val_loss: 0.9242 - val_accuracy: 0.5411 - val_recall_with_logits_5: 0.5302 - val_precision_with_logits_5: 0.7745 - val_balanced_accuracy: 0.4943 - val_mcc: 0.0095 - val_f1: 0.5712
# Epoch 76/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9122 - accuracy: 0.5654 - recall_with_logits_5: 0.5557 - precision_with_logits_5: 0.7973 - balanced_accuracy: 0.6677 - mcc: 0.2844 - f1: 0.6609 - val_loss: 0.9209 - val_accuracy: 0.5197 - val_recall_with_logits_5: 0.5067 - val_precision_with_logits_5: 0.7617 - val_balanced_accuracy: 0.4808 - val_mcc: 0.0301 - val_f1: 0.5245
# Epoch 77/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9125 - accuracy: 0.5736 - recall_with_logits_5: 0.5649 - precision_with_logits_5: 0.8009 - balanced_accuracy: 0.5175 - mcc: 0.0312 - f1: 0.5115 - val_loss: 0.9216 - val_accuracy: 0.5082 - val_recall_with_logits_5: 0.5011 - val_precision_with_logits_5: 0.7467 - val_balanced_accuracy: 0.5000 - val_mcc: 0.0000e+00 - val_f1: 0.4643
# Epoch 78/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.9117 - accuracy: 0.5720 - recall_with_logits_5: 0.5713 - precision_with_logits_5: 0.7928 - balanced_accuracy: 0.5536 - mcc: 0.0887 - f1: 0.5635 - val_loss: 0.9167 - val_accuracy: 0.5378 - val_recall_with_logits_5: 0.5434 - val_precision_with_logits_5: 0.7625 - val_balanced_accuracy: 0.5179 - val_mcc: 0.0237 - val_f1: 0.6096
# Epoch 79/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9072 - accuracy: 0.5654 - recall_with_logits_5: 0.5529 - precision_with_logits_5: 0.7997 - balanced_accuracy: 0.5385 - mcc: 0.0645 - f1: 0.5693 - val_loss: 0.9148 - val_accuracy: 0.5461 - val_recall_with_logits_5: 0.5436 - val_precision_with_logits_5: 0.7714 - val_balanced_accuracy: 0.6609 - val_mcc: 0.1938 - val_f1: 0.7278
# Epoch 80/200
# 19/19 [==============================] - 30s 2s/step - loss: 0.9029 - accuracy: 0.5826 - recall_with_logits_5: 0.5684 - precision_with_logits_5: 0.8130 - balanced_accuracy: 0.5820 - mcc: 0.1435 - f1: 0.5972 - val_loss: 0.9113 - val_accuracy: 0.5510 - val_recall_with_logits_5: 0.5546 - val_precision_with_logits_5: 0.7733 - val_balanced_accuracy: 0.5963 - val_mcc: 0.1410 - val_f1: 0.6493
# Epoch 81/200
# 19/19 [==============================] - 30s 2s/step - loss: 0.9054 - accuracy: 0.5674 - recall_with_logits_5: 0.5604 - precision_with_logits_5: 0.7935 - balanced_accuracy: 0.5936 - mcc: 0.1685 - f1: 0.6067 - val_loss: 0.9095 - val_accuracy: 0.5641 - val_recall_with_logits_5: 0.5733 - val_precision_with_logits_5: 0.7795 - val_balanced_accuracy: 0.7244 - val_mcc: 0.3510 - val_f1: 0.6939
# Epoch 82/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.9017 - accuracy: 0.5789 - recall_with_logits_5: 0.5786 - precision_with_logits_5: 0.7972 - balanced_accuracy: 0.5777 - mcc: 0.1359 - f1: 0.6346 - val_loss: 0.9078 - val_accuracy: 0.5707 - val_recall_with_logits_5: 0.5800 - val_precision_with_logits_5: 0.7838 - val_balanced_accuracy: 0.8103 - val_mcc: 0.3647 - val_f1: 0.7272
# Epoch 83/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.8988 - accuracy: 0.5822 - recall_with_logits_5: 0.5760 - precision_with_logits_5: 0.8029 - balanced_accuracy: 0.5499 - mcc: 0.0933 - f1: 0.5693 - val_loss: 0.9082 - val_accuracy: 0.5477 - val_recall_with_logits_5: 0.5513 - val_precision_with_logits_5: 0.7695 - val_balanced_accuracy: 0.3974 - val_mcc: 0.1601 - val_f1: 0.4984
# Epoch 84/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.8922 - accuracy: 0.5946 - recall_with_logits_5: 0.5828 - precision_with_logits_5: 0.8187 - balanced_accuracy: 0.6250 - mcc: 0.2328 - f1: 0.6381 - val_loss: 0.9070 - val_accuracy: 0.5543 - val_recall_with_logits_5: 0.5692 - val_precision_with_logits_5: 0.7658 - val_balanced_accuracy: 0.5778 - val_mcc: 0.1132 - val_f1: 0.6222
# Epoch 85/200
# 19/19 [==============================] - 30s 2s/step - loss: 0.8920 - accuracy: 0.5909 - recall_with_logits_5: 0.5862 - precision_with_logits_5: 0.8077 - balanced_accuracy: 0.5831 - mcc: 0.1391 - f1: 0.5980 - val_loss: 0.9011 - val_accuracy: 0.5510 - val_recall_with_logits_5: 0.5499 - val_precision_with_logits_5: 0.7799 - val_balanced_accuracy: 0.6410 - val_mcc: 0.2219 - val_f1: 0.6659
# Epoch 86/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.8880 - accuracy: 0.6012 - recall_with_logits_5: 0.5906 - precision_with_logits_5: 0.8202 - balanced_accuracy: 0.5266 - mcc: 0.0486 - f1: 0.5814 - val_loss: 0.8989 - val_accuracy: 0.5411 - val_recall_with_logits_5: 0.5344 - val_precision_with_logits_5: 0.7774 - val_balanced_accuracy: 0.6159 - val_mcc: 0.2085 - val_f1: 0.6142
# Epoch 87/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.8868 - accuracy: 0.5847 - recall_with_logits_5: 0.5744 - precision_with_logits_5: 0.8099 - balanced_accuracy: 0.6129 - mcc: 0.1980 - f1: 0.6264 - val_loss: 0.8978 - val_accuracy: 0.5477 - val_recall_with_logits_5: 0.5367 - val_precision_with_logits_5: 0.7825 - val_balanced_accuracy: 0.5771 - val_mcc: 0.1299 - val_f1: 0.5364
# Epoch 88/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.8880 - accuracy: 0.5798 - recall_with_logits_5: 0.5717 - precision_with_logits_5: 0.8039 - balanced_accuracy: 0.5797 - mcc: 0.1436 - f1: 0.5992 - val_loss: 0.8984 - val_accuracy: 0.5428 - val_recall_with_logits_5: 0.5412 - val_precision_with_logits_5: 0.7714 - val_balanced_accuracy: 0.6771 - val_mcc: 0.2952 - val_f1: 0.6856
# Epoch 89/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.8815 - accuracy: 0.6044 - recall_with_logits_5: 0.5972 - precision_with_logits_5: 0.8194 - balanced_accuracy: 0.5392 - mcc: 0.0636 - f1: 0.6048 - val_loss: 0.8977 - val_accuracy: 0.5345 - val_recall_with_logits_5: 0.5379 - val_precision_with_logits_5: 0.7603 - val_balanced_accuracy: 0.5346 - val_mcc: 0.0658 - val_f1: 0.5430
# Epoch 90/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.8790 - accuracy: 0.5975 - recall_with_logits_5: 0.5875 - precision_with_logits_5: 0.8176 - balanced_accuracy: 0.5682 - mcc: 0.1240 - f1: 0.6053 - val_loss: 0.8947 - val_accuracy: 0.5477 - val_recall_with_logits_5: 0.5511 - val_precision_with_logits_5: 0.7726 - val_balanced_accuracy: 0.6061 - val_mcc: 0.2051 - val_f1: 0.6312
# Epoch 91/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.8785 - accuracy: 0.6024 - recall_with_logits_5: 0.5944 - precision_with_logits_5: 0.8187 - balanced_accuracy: 0.5171 - mcc: 0.0289 - f1: 0.5896 - val_loss: 0.8930 - val_accuracy: 0.5312 - val_recall_with_logits_5: 0.5246 - val_precision_with_logits_5: 0.7655 - val_balanced_accuracy: 0.6083 - val_mcc: 0.2102 - val_f1: 0.5998
# Epoch 92/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.8777 - accuracy: 0.5917 - recall_with_logits_5: 0.5875 - precision_with_logits_5: 0.8089 - balanced_accuracy: 0.5545 - mcc: 0.0854 - f1: 0.6105 - val_loss: 0.8936 - val_accuracy: 0.5197 - val_recall_with_logits_5: 0.5213 - val_precision_with_logits_5: 0.7492 - val_balanced_accuracy: 0.6037 - val_mcc: 0.1556 - val_f1: 0.5260
# Epoch 93/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.8712 - accuracy: 0.6127 - recall_with_logits_5: 0.6080 - precision_with_logits_5: 0.8227 - balanced_accuracy: 0.6182 - mcc: 0.2074 - f1: 0.6336 - val_loss: 0.8889 - val_accuracy: 0.5230 - val_recall_with_logits_5: 0.5246 - val_precision_with_logits_5: 0.7532 - val_balanced_accuracy: 0.3958 - val_mcc: 0.1837 - val_f1: 0.5011
# Epoch 94/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.8726 - accuracy: 0.6036 - recall_with_logits_5: 0.6068 - precision_with_logits_5: 0.8110 - balanced_accuracy: 0.5389 - mcc: 0.0715 - f1: 0.5729 - val_loss: 0.8843 - val_accuracy: 0.5674 - val_recall_with_logits_5: 0.5756 - val_precision_with_logits_5: 0.7825 - val_balanced_accuracy: 0.3727 - val_mcc: 0.2437 - val_f1: 0.4497
# Epoch 95/200
# 19/19 [==============================] - 31s 2s/step - loss: 0.8705 - accuracy: 0.5966 - recall_with_logits_5: 0.5987 - precision_with_logits_5: 0.8078 - balanced_accuracy: 0.5499 - mcc: 0.0933 - f1: 0.5693 - val_loss: 0.8815 - val_accuracy: 0.5641 - val_recall_with_logits_5: 0.5819 - val_precision_with_logits_5: 0.7758 - val_balanced_accuracy: 0.5833 - val_mcc: 0.1443 - val_f1: 0.5917
# Epoch 96/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.8639 - accuracy: 0.6151 - recall_with_logits_5: 0.6038 - precision_with_logits_5: 0.8305 - balanced_accuracy: 0.6836 - mcc: 0.2958 - f1: 0.6686 - val_loss: 0.8816 - val_accuracy: 0.5674 - val_recall_with_logits_5: 0.5804 - val_precision_with_logits_5: 0.7761 - val_balanced_accuracy: 0.4500 - val_mcc: 0.1044 - val_f1: 0.4892
# Epoch 97/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.8682 - accuracy: 0.6007 - recall_with_logits_5: 0.6037 - precision_with_logits_5: 0.8080 - balanced_accuracy: 0.5821 - mcc: 0.1489 - f1: 0.6131 - val_loss: 0.8808 - val_accuracy: 0.5428 - val_recall_with_logits_5: 0.5402 - val_precision_with_logits_5: 0.7707 - val_balanced_accuracy: 0.3455 - val_mcc: 0.3091 - val_f1: 0.4375
# Epoch 98/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.8624 - accuracy: 0.6094 - recall_with_logits_5: 0.6079 - precision_with_logits_5: 0.8185 - balanced_accuracy: 0.5986 - mcc: 0.1637 - f1: 0.6288 - val_loss: 0.8771 - val_accuracy: 0.5362 - val_recall_with_logits_5: 0.5312 - val_precision_with_logits_5: 0.7677 - val_balanced_accuracy: 0.5208 - val_mcc: 0.0367 - val_f1: 0.4980
# Epoch 99/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.8605 - accuracy: 0.5962 - recall_with_logits_5: 0.5851 - precision_with_logits_5: 0.8185 - balanced_accuracy: 0.4622 - mcc: 0.0715 - f1: 0.4907 - val_loss: 0.8759 - val_accuracy: 0.5559 - val_recall_with_logits_5: 0.5612 - val_precision_with_logits_5: 0.7754 - val_balanced_accuracy: 0.6113 - val_mcc: 0.2227 - val_f1: 0.6250
# Epoch 100/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.8575 - accuracy: 0.6246 - recall_with_logits_5: 0.6244 - precision_with_logits_5: 0.8259 - balanced_accuracy: 0.5895 - mcc: 0.1642 - f1: 0.6107 - val_loss: 0.8749 - val_accuracy: 0.5493 - val_recall_with_logits_5: 0.5568 - val_precision_with_logits_5: 0.7692 - val_balanced_accuracy: 0.4792 - val_mcc: 0.0362 - val_f1: 0.5031
# Epoch 101/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.8574 - accuracy: 0.6003 - recall_with_logits_5: 0.5935 - precision_with_logits_5: 0.8150 - balanced_accuracy: 0.6516 - mcc: 0.2729 - f1: 0.6513 - val_loss: 0.8706 - val_accuracy: 0.5493 - val_recall_with_logits_5: 0.5556 - val_precision_with_logits_5: 0.7716 - val_balanced_accuracy: 0.7667 - val_mcc: 0.5164 - val_f1: 0.7540
# Epoch 102/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.8530 - accuracy: 0.6061 - recall_with_logits_5: 0.5971 - precision_with_logits_5: 0.8226 - balanced_accuracy: 0.6546 - mcc: 0.2922 - f1: 0.6428 - val_loss: 0.8704 - val_accuracy: 0.5329 - val_recall_with_logits_5: 0.5333 - val_precision_with_logits_5: 0.7643 - val_balanced_accuracy: 0.5417 - val_mcc: 0.0727 - val_f1: 0.5909
# Epoch 103/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.8458 - accuracy: 0.6184 - recall_with_logits_5: 0.6130 - precision_with_logits_5: 0.8295 - balanced_accuracy: 0.6696 - mcc: 0.3077 - f1: 0.6497 - val_loss: 0.8681 - val_accuracy: 0.5543 - val_recall_with_logits_5: 0.5654 - val_precision_with_logits_5: 0.7727 - val_balanced_accuracy: 0.5169 - val_mcc: 0.0305 - val_f1: 0.5243
# Epoch 104/200
# 19/19 [==============================] - 33s 2s/step - loss: 0.8503 - accuracy: 0.6069 - recall_with_logits_5: 0.5902 - precision_with_logits_5: 0.8298 - balanced_accuracy: 0.6641 - mcc: 0.2821 - f1: 0.6662 - val_loss: 0.8657 - val_accuracy: 0.5724 - val_recall_with_logits_5: 0.5867 - val_precision_with_logits_5: 0.7811 - val_balanced_accuracy: 0.6682 - val_mcc: 0.3124 - val_f1: 0.6686
# Epoch 105/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.8451 - accuracy: 0.6271 - recall_with_logits_5: 0.6337 - precision_with_logits_5: 0.8222 - balanced_accuracy: 0.6375 - mcc: 0.2505 - f1: 0.6494 - val_loss: 0.8641 - val_accuracy: 0.5592 - val_recall_with_logits_5: 0.5889 - val_precision_with_logits_5: 0.7615 - val_balanced_accuracy: 0.7083 - val_mcc: 0.3892 - val_f1: 0.7585
# Epoch 106/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.8506 - accuracy: 0.6131 - recall_with_logits_5: 0.6221 - precision_with_logits_5: 0.8101 - balanced_accuracy: 0.6108 - mcc: 0.1958 - f1: 0.6174 - val_loss: 0.8636 - val_accuracy: 0.5707 - val_recall_with_logits_5: 0.6071 - val_precision_with_logits_5: 0.7619 - val_balanced_accuracy: 0.5714 - val_mcc: 0.0976 - val_f1: 0.6875
# Epoch 107/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.8462 - accuracy: 0.6143 - recall_with_logits_5: 0.6093 - precision_with_logits_5: 0.8227 - balanced_accuracy: 0.5510 - mcc: 0.0911 - f1: 0.5787 - val_loss: 0.8625 - val_accuracy: 0.5789 - val_recall_with_logits_5: 0.6036 - val_precision_with_logits_5: 0.7765 - val_balanced_accuracy: 0.5700 - val_mcc: 0.1326 - val_f1: 0.6352
# Epoch 108/200
# 19/19 [==============================] - 33s 2s/step - loss: 0.8395 - accuracy: 0.6135 - recall_with_logits_5: 0.6115 - precision_with_logits_5: 0.8212 - balanced_accuracy: 0.6485 - mcc: 0.2714 - f1: 0.6639 - val_loss: 0.8624 - val_accuracy: 0.5674 - val_recall_with_logits_5: 0.5893 - val_precision_with_logits_5: 0.7697 - val_balanced_accuracy: 0.5963 - val_mcc: 0.1410 - val_f1: 0.6493
# Epoch 109/200
# 19/19 [==============================] - 33s 2s/step - loss: 0.8352 - accuracy: 0.6336 - recall_with_logits_5: 0.6341 - precision_with_logits_5: 0.8320 - balanced_accuracy: 0.6603 - mcc: 0.2864 - f1: 0.6899 - val_loss: 0.8576 - val_accuracy: 0.5526 - val_recall_with_logits_5: 0.5638 - val_precision_with_logits_5: 0.7660 - val_balanced_accuracy: 0.5417 - val_mcc: 0.0808 - val_f1: 0.5382
# Epoch 110/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.8384 - accuracy: 0.6135 - recall_with_logits_5: 0.6151 - precision_with_logits_5: 0.8168 - balanced_accuracy: 0.6161 - mcc: 0.2053 - f1: 0.6248 - val_loss: 0.8576 - val_accuracy: 0.5510 - val_recall_with_logits_5: 0.5670 - val_precision_with_logits_5: 0.7628 - val_balanced_accuracy: 0.3629 - val_mcc: 0.2268 - val_f1: 0.4573
# Epoch 111/200
# 19/19 [==============================] - 33s 2s/step - loss: 0.8326 - accuracy: 0.6131 - recall_with_logits_5: 0.6170 - precision_with_logits_5: 0.8150 - balanced_accuracy: 0.5417 - mcc: 0.0723 - f1: 0.5771 - val_loss: 0.8555 - val_accuracy: 0.5576 - val_recall_with_logits_5: 0.5692 - val_precision_with_logits_5: 0.7704 - val_balanced_accuracy: 0.6455 - val_mcc: 0.2697 - val_f1: 0.6387
# Epoch 112/200
# 19/19 [==============================] - 33s 2s/step - loss: 0.8269 - accuracy: 0.6345 - recall_with_logits_5: 0.6192 - precision_with_logits_5: 0.8469 - balanced_accuracy: 0.6830 - mcc: 0.3114 - f1: 0.6823 - val_loss: 0.8552 - val_accuracy: 0.5625 - val_recall_with_logits_5: 0.5880 - val_precision_with_logits_5: 0.7652 - val_balanced_accuracy: 0.5918 - val_mcc: 0.1781 - val_f1: 0.6615
# Epoch 113/200
# 19/19 [==============================] - 33s 2s/step - loss: 0.8295 - accuracy: 0.6250 - recall_with_logits_5: 0.6346 - precision_with_logits_5: 0.8182 - balanced_accuracy: 0.6079 - mcc: 0.2016 - f1: 0.6375 - val_loss: 0.8534 - val_accuracy: 0.5691 - val_recall_with_logits_5: 0.6080 - val_precision_with_logits_5: 0.7604 - val_balanced_accuracy: 0.5409 - val_mcc: 0.0798 - val_f1: 0.5987
# Epoch 114/200
# 19/19 [==============================] - 33s 2s/step - loss: 0.8279 - accuracy: 0.6373 - recall_with_logits_5: 0.6489 - precision_with_logits_5: 0.8237 - balanced_accuracy: 0.6354 - mcc: 0.2550 - f1: 0.6436 - val_loss: 0.8509 - val_accuracy: 0.5641 - val_recall_with_logits_5: 0.5960 - val_precision_with_logits_5: 0.7607 - val_balanced_accuracy: 0.4744 - val_mcc: 0.0413 - val_f1: 0.6069
# Epoch 115/200
# 19/19 [==============================] - 33s 2s/step - loss: 0.8216 - accuracy: 0.6460 - recall_with_logits_5: 0.6479 - precision_with_logits_5: 0.8363 - balanced_accuracy: 0.6275 - mcc: 0.2334 - f1: 0.6106 - val_loss: 0.8454 - val_accuracy: 0.5938 - val_recall_with_logits_5: 0.6362 - val_precision_with_logits_5: 0.7724 - val_balanced_accuracy: 0.5833 - val_mcc: 0.1491 - val_f1: 0.6455
# Epoch 116/200
# 19/19 [==============================] - 33s 2s/step - loss: 0.8219 - accuracy: 0.6439 - recall_with_logits_5: 0.6410 - precision_with_logits_5: 0.8406 - balanced_accuracy: 0.6823 - mcc: 0.2987 - f1: 0.6807 - val_loss: 0.8436 - val_accuracy: 0.5839 - val_recall_with_logits_5: 0.6116 - val_precision_with_logits_5: 0.7762 - val_balanced_accuracy: 0.4543 - val_mcc: 0.0756 - val_f1: 0.5144
# Epoch 117/200
# 19/19 [==============================] - 33s 2s/step - loss: 0.8152 - accuracy: 0.6390 - recall_with_logits_5: 0.6395 - precision_with_logits_5: 0.8357 - balanced_accuracy: 0.7083 - mcc: 0.3962 - f1: 0.7028 - val_loss: 0.8459 - val_accuracy: 0.5872 - val_recall_with_logits_5: 0.6233 - val_precision_with_logits_5: 0.7701 - val_balanced_accuracy: 0.4221 - val_mcc: 0.1529 - val_f1: 0.4738
# Epoch 118/200
# 19/19 [==============================] - 32s 2s/step - loss: 0.8174 - accuracy: 0.6447 - recall_with_logits_5: 0.6543 - precision_with_logits_5: 0.8303 - balanced_accuracy: 0.5676 - mcc: 0.1256 - f1: 0.6237 - val_loss: 0.8399 - val_accuracy: 0.5806 - val_recall_with_logits_5: 0.6098 - val_precision_with_logits_5: 0.7768 - val_balanced_accuracy: 0.5577 - val_mcc: 0.0917 - val_f1: 0.6370
# Epoch 119/200
# ...
# Epoch 162/200
# 19/19 [==============================] - 40s 2s/step - loss: 0.7111 - accuracy: 0.7134 - recall_with_logits_5: 0.7226 - precision_with_logits_5: 0.8678 - balanced_accuracy: 0.6398 - mcc: 0.2290 - f1: 0.6959 - val_loss: 0.7763 - val_accuracy: 0.6332 - val_recall_with_logits_5: 0.6846 - val_precision_with_logits_5: 0.7887 - val_balanced_accuracy: 0.4155 - val_mcc: 0.1601 - val_f1: 0.5136
# Epoch 163/200
# 19/19 [==============================] - 40s 2s/step - loss: 0.7061 - accuracy: 0.7237 - recall_with_logits_5: 0.7233 - precision_with_logits_5: 0.8821 - balanced_accuracy: 0.7736 - mcc: 0.4569 - f1: 0.7497 - val_loss: 0.7741 - val_accuracy: 0.6168 - val_recall_with_logits_5: 0.6592 - val_precision_with_logits_5: 0.7840 - val_balanced_accuracy: 0.6143 - val_mcc: 0.2182 - val_f1: 0.7253
# Epoch 164/200
# 19/19 [==============================] - 41s 2s/step - loss: 0.7036 - accuracy: 0.7286 - recall_with_logits_5: 0.7279 - precision_with_logits_5: 0.8852 - balanced_accuracy: 0.6736 - mcc: 0.3038 - f1: 0.7298 - val_loss: 0.7724 - val_accuracy: 0.6168 - val_recall_with_logits_5: 0.6726 - val_precision_with_logits_5: 0.7784 - val_balanced_accuracy: 0.5909 - val_mcc: 0.1741 - val_f1: 0.6331
# Epoch 165/200
# 19/19 [==============================] - 40s 2s/step - loss: 0.7057 - accuracy: 0.7245 - recall_with_logits_5: 0.7319 - precision_with_logits_5: 0.8750 - balanced_accuracy: 0.7032 - mcc: 0.3291 - f1: 0.6967 - val_loss: 0.7683 - val_accuracy: 0.6382 - val_recall_with_logits_5: 0.7044 - val_precision_with_logits_5: 0.7847 - val_balanced_accuracy: 0.5364 - val_mcc: 0.0778 - val_f1: 0.6123
# Epoch 166/200
# 19/19 [==============================] - 41s 2s/step - loss: 0.6990 - accuracy: 0.7340 - recall_with_logits_5: 0.7389 - precision_with_logits_5: 0.8817 - balanced_accuracy: 0.7298 - mcc: 0.4320 - f1: 0.7425 - val_loss: 0.7658 - val_accuracy: 0.6217 - val_recall_with_logits_5: 0.6734 - val_precision_with_logits_5: 0.7818 - val_balanced_accuracy: 0.6042 - val_mcc: 0.1899 - val_f1: 0.6719
# Epoch 167/200
# 19/19 [==============================] - 40s 2s/step - loss: 0.6941 - accuracy: 0.7229 - recall_with_logits_5: 0.7210 - precision_with_logits_5: 0.8838 - balanced_accuracy: 0.6325 - mcc: 0.2435 - f1: 0.6479 - val_loss: 0.7642 - val_accuracy: 0.6217 - val_recall_with_logits_5: 0.6704 - val_precision_with_logits_5: 0.7859 - val_balanced_accuracy: 0.6458 - val_mcc: 0.2572 - val_f1: 0.6772
# Epoch 168/200
# 19/19 [==============================] - 41s 2s/step - loss: 0.6922 - accuracy: 0.7348 - recall_with_logits_5: 0.7367 - precision_with_logits_5: 0.8858 - balanced_accuracy: 0.7493 - mcc: 0.4424 - f1: 0.7720 - val_loss: 0.7673 - val_accuracy: 0.6349 - val_recall_with_logits_5: 0.6964 - val_precision_with_logits_5: 0.7839 - val_balanced_accuracy: 0.5625 - val_mcc: 0.1204 - val_f1: 0.6627
# Epoch 169/200
# 19/19 [==============================] - 41s 2s/step - loss: 0.6873 - accuracy: 0.7430 - recall_with_logits_5: 0.7489 - precision_with_logits_5: 0.8863 - balanced_accuracy: 0.7826 - mcc: 0.5351 - f1: 0.8024 - val_loss: 0.7683 - val_accuracy: 0.6530 - val_recall_with_logits_5: 0.7350 - val_precision_with_logits_5: 0.7820 - val_balanced_accuracy: 0.6500 - val_mcc: 0.3133 - val_f1: 0.6807
# Epoch 170/200
# 19/19 [==============================] - 40s 2s/step - loss: 0.6875 - accuracy: 0.7516 - recall_with_logits_5: 0.7553 - precision_with_logits_5: 0.8922 - balanced_accuracy: 0.7788 - mcc: 0.5000 - f1: 0.7706 - val_loss: 0.7619 - val_accuracy: 0.6332 - val_recall_with_logits_5: 0.6956 - val_precision_with_logits_5: 0.7845 - val_balanced_accuracy: 0.5833 - val_mcc: 0.1491 - val_f1: 0.6455
# Epoch 171/200
# 19/19 [==============================] - 40s 2s/step - loss: 0.6809 - accuracy: 0.7463 - recall_with_logits_5: 0.7463 - precision_with_logits_5: 0.8936 - balanced_accuracy: 0.6776 - mcc: 0.3290 - f1: 0.6842 - val_loss: 0.7668 - val_accuracy: 0.6118 - val_recall_with_logits_5: 0.6726 - val_precision_with_logits_5: 0.7724 - val_balanced_accuracy: 0.5667 - val_mcc: 0.0667 - val_f1: 0.7214
# Epoch 172/200
# 19/19 [==============================] - 41s 2s/step - loss: 0.6790 - accuracy: 0.7405 - recall_with_logits_5: 0.7350 - precision_with_logits_5: 0.8957 - balanced_accuracy: 0.8108 - mcc: 0.5180 - f1: 0.7859 - val_loss: 0.7555 - val_accuracy: 0.6365 - val_recall_with_logits_5: 0.7000 - val_precision_with_logits_5: 0.7855 - val_balanced_accuracy: 0.6409 - val_mcc: 0.2660 - val_f1: 0.6661
# Epoch 173/200
# 19/19 [==============================] - 41s 2s/step - loss: 0.6793 - accuracy: 0.7525 - recall_with_logits_5: 0.7600 - precision_with_logits_5: 0.8895 - balanced_accuracy: 0.7097 - mcc: 0.3988 - f1: 0.7334 - val_loss: 0.7650 - val_accuracy: 0.6447 - val_recall_with_logits_5: 0.7366 - val_precision_with_logits_5: 0.7710 - val_balanced_accuracy: 0.5081 - val_mcc: 0.0164 - val_f1: 0.5279
# Epoch 174/200
# 19/19 [==============================] - 40s 2s/step - loss: 0.6702 - accuracy: 0.7545 - recall_with_logits_5: 0.7508 - precision_with_logits_5: 0.9006 - balanced_accuracy: 0.8122 - mcc: 0.5357 - f1: 0.7828 - val_loss: 0.7593 - val_accuracy: 0.6365 - val_recall_with_logits_5: 0.6897 - val_precision_with_logits_5: 0.7903 - val_balanced_accuracy: 0.6250 - val_mcc: 0.1839 - val_f1: 0.7590
# Epoch 175/200
# 19/19 [==============================] - 40s 2s/step - loss: 0.6729 - accuracy: 0.7549 - recall_with_logits_5: 0.7621 - precision_with_logits_5: 0.8908 - balanced_accuracy: 0.8073 - mcc: 0.5703 - f1: 0.8270 - val_loss: 0.7596 - val_accuracy: 0.6480 - val_recall_with_logits_5: 0.7321 - val_precision_with_logits_5: 0.7773 - val_balanced_accuracy: 0.6074 - val_mcc: 0.1887 - val_f1: 0.7660
# Epoch 176/200
# 19/19 [==============================] - 41s 2s/step - loss: 0.6664 - accuracy: 0.7562 - recall_with_logits_5: 0.7533 - precision_with_logits_5: 0.9002 - balanced_accuracy: 0.7849 - mcc: 0.4951 - f1: 0.8035 - val_loss: 0.7599 - val_accuracy: 0.6447 - val_recall_with_logits_5: 0.7181 - val_precision_with_logits_5: 0.7810 - val_balanced_accuracy: 0.6111 - val_mcc: 0.2277 - val_f1: 0.6204
# Epoch 177/200
# 19/19 [==============================] - 42s 2s/step - loss: 0.6693 - accuracy: 0.7463 - recall_with_logits_5: 0.7433 - precision_with_logits_5: 0.8970 - balanced_accuracy: 0.7123 - mcc: 0.3890 - f1: 0.7459 - val_loss: 0.7604 - val_accuracy: 0.6316 - val_recall_with_logits_5: 0.6928 - val_precision_with_logits_5: 0.7803 - val_balanced_accuracy: 0.6812 - val_mcc: 0.3317 - val_f1: 0.7010
# Epoch 178/200
# 19/19 [==============================] - 41s 2s/step - loss: 0.6622 - accuracy: 0.7582 - recall_with_logits_5: 0.7614 - precision_with_logits_5: 0.8967 - balanced_accuracy: 0.7523 - mcc: 0.4211 - f1: 0.7645 - val_loss: 0.7601 - val_accuracy: 0.6530 - val_recall_with_logits_5: 0.7162 - val_precision_with_logits_5: 0.7956 - val_balanced_accuracy: 0.6250 - val_mcc: 0.2335 - val_f1: 0.6981
# Epoch 179/200
# 19/19 [==============================] - 42s 2s/step - loss: 0.6572 - accuracy: 0.7619 - recall_with_logits_5: 0.7673 - precision_with_logits_5: 0.8954 - balanced_accuracy: 0.8138 - mcc: 0.5651 - f1: 0.7924 - val_loss: 0.7531 - val_accuracy: 0.6184 - val_recall_with_logits_5: 0.6608 - val_precision_with_logits_5: 0.7905 - val_balanced_accuracy: 0.6039 - val_mcc: 0.1902 - val_f1: 0.6412
# Epoch 180/200
# 19/19 [==============================] - 41s 2s/step - loss: 0.6547 - accuracy: 0.7656 - recall_with_logits_5: 0.7579 - precision_with_logits_5: 0.9106 - balanced_accuracy: 0.8373 - mcc: 0.6346 - f1: 0.8485 - val_loss: 0.7581 - val_accuracy: 0.6431 - val_recall_with_logits_5: 0.7082 - val_precision_with_logits_5: 0.7871 - val_balanced_accuracy: 0.6538 - val_mcc: 0.2774 - val_f1: 0.7629
# Epoch 181/200
# 19/19 [==============================] - 41s 2s/step - loss: 0.6509 - accuracy: 0.7689 - recall_with_logits_5: 0.7635 - precision_with_logits_5: 0.9092 - balanced_accuracy: 0.7354 - mcc: 0.3911 - f1: 0.7363 - val_loss: 0.7516 - val_accuracy: 0.6201 - val_recall_with_logits_5: 0.6652 - val_precision_with_logits_5: 0.7895 - val_balanced_accuracy: 0.7372 - val_mcc: 0.4118 - val_f1: 0.7964
# Epoch 182/200
# 19/19 [==============================] - 41s 2s/step - loss: 0.6498 - accuracy: 0.7623 - recall_with_logits_5: 0.7615 - precision_with_logits_5: 0.9019 - balanced_accuracy: 0.7624 - mcc: 0.4688 - f1: 0.7637 - val_loss: 0.7525 - val_accuracy: 0.6365 - val_recall_with_logits_5: 0.6925 - val_precision_with_logits_5: 0.7924 - val_balanced_accuracy: 0.5918 - val_mcc: 0.1781 - val_f1: 0.6615
# Epoch 183/200
# 19/19 [==============================] - 41s 2s/step - loss: 0.6532 - accuracy: 0.7611 - recall_with_logits_5: 0.7661 - precision_with_logits_5: 0.8953 - balanced_accuracy: 0.7929 - mcc: 0.5909 - f1: 0.8352 - val_loss: 0.7539 - val_accuracy: 0.6497 - val_recall_with_logits_5: 0.7054 - val_precision_with_logits_5: 0.7960 - val_balanced_accuracy: 0.6410 - val_mcc: 0.2219 - val_f1: 0.6659
# Epoch 184/200
# 19/19 [==============================] - 41s 2s/step - loss: 0.6439 - accuracy: 0.7866 - recall_with_logits_5: 0.7876 - precision_with_logits_5: 0.9126 - balanced_accuracy: 0.7627 - mcc: 0.4739 - f1: 0.7849 - val_loss: 0.7518 - val_accuracy: 0.6365 - val_recall_with_logits_5: 0.7029 - val_precision_with_logits_5: 0.7847 - val_balanced_accuracy: 0.5909 - val_mcc: 0.1741 - val_f1: 0.6331
# Epoch 185/200
# 19/19 [==============================] - 41s 2s/step - loss: 0.6358 - accuracy: 0.7792 - recall_with_logits_5: 0.7773 - precision_with_logits_5: 0.9115 - balanced_accuracy: 0.8604 - mcc: 0.6639 - f1: 0.8576 - val_loss: 0.7562 - val_accuracy: 0.6365 - val_recall_with_logits_5: 0.7089 - val_precision_with_logits_5: 0.7800 - val_balanced_accuracy: 0.7126 - val_mcc: 0.2757 - val_f1: 0.7981
# Epoch 186/200
# 19/19 [==============================] - 42s 2s/step - loss: 0.6439 - accuracy: 0.7722 - recall_with_logits_5: 0.7812 - precision_with_logits_5: 0.8987 - balanced_accuracy: 0.8195 - mcc: 0.6421 - f1: 0.8355 - val_loss: 0.7610 - val_accuracy: 0.6382 - val_recall_with_logits_5: 0.7321 - val_precision_with_logits_5: 0.7664 - val_balanced_accuracy: 0.4909 - val_mcc: 0.0182 - val_f1: 0.5625
# Epoch 187/200
# 19/19 [==============================] - 42s 2s/step - loss: 0.6356 - accuracy: 0.7734 - recall_with_logits_5: 0.7783 - precision_with_logits_5: 0.9013 - balanced_accuracy: 0.7742 - mcc: 0.5250 - f1: 0.8013 - val_loss: 0.7533 - val_accuracy: 0.6480 - val_recall_with_logits_5: 0.7299 - val_precision_with_logits_5: 0.7786 - val_balanced_accuracy: 0.5128 - val_mcc: 0.0216 - val_f1: 0.6562
# Epoch 188/200
# 19/19 [==============================] - 42s 2s/step - loss: 0.6327 - accuracy: 0.7743 - recall_with_logits_5: 0.7652 - precision_with_logits_5: 0.9154 - balanced_accuracy: 0.8038 - mcc: 0.5893 - f1: 0.8000 - val_loss: 0.7512 - val_accuracy: 0.6217 - val_recall_with_logits_5: 0.6927 - val_precision_with_logits_5: 0.7717 - val_balanced_accuracy: 0.4583 - val_mcc: 0.0778 - val_f1: 0.5773
# Epoch 189/200
# 19/19 [==============================] - 42s 2s/step - loss: 0.6251 - accuracy: 0.7919 - recall_with_logits_5: 0.7854 - precision_with_logits_5: 0.9217 - balanced_accuracy: 0.7728 - mcc: 0.5023 - f1: 0.7827 - val_loss: 0.7484 - val_accuracy: 0.6365 - val_recall_with_logits_5: 0.7016 - val_precision_with_logits_5: 0.7836 - val_balanced_accuracy: 0.7182 - val_mcc: 0.4045 - val_f1: 0.6989
# Epoch 190/200
# 19/19 [==============================] - 42s 2s/step - loss: 0.6196 - accuracy: 0.7989 - recall_with_logits_5: 0.8008 - precision_with_logits_5: 0.9174 - balanced_accuracy: 0.7408 - mcc: 0.4514 - f1: 0.7352 - val_loss: 0.7405 - val_accuracy: 0.6497 - val_recall_with_logits_5: 0.7156 - val_precision_with_logits_5: 0.7912 - val_balanced_accuracy: 0.6135 - val_mcc: 0.2271 - val_f1: 0.6875
# Epoch 191/200
# 19/19 [==============================] - 41s 2s/step - loss: 0.6234 - accuracy: 0.7800 - recall_with_logits_5: 0.7834 - precision_with_logits_5: 0.9076 - balanced_accuracy: 0.7524 - mcc: 0.4507 - f1: 0.7713 - val_loss: 0.7474 - val_accuracy: 0.6332 - val_recall_with_logits_5: 0.6904 - val_precision_with_logits_5: 0.7868 - val_balanced_accuracy: 0.5821 - val_mcc: 0.1489 - val_f1: 0.6131
# Epoch 192/200
# 19/19 [==============================] - 42s 2s/step - loss: 0.6214 - accuracy: 0.7903 - recall_with_logits_5: 0.7945 - precision_with_logits_5: 0.9116 - balanced_accuracy: 0.8099 - mcc: 0.6198 - f1: 0.8437 - val_loss: 0.7515 - val_accuracy: 0.6349 - val_recall_with_logits_5: 0.6949 - val_precision_with_logits_5: 0.7859 - val_balanced_accuracy: 0.4372 - val_mcc: 0.1218 - val_f1: 0.5384
# Epoch 193/200
# 19/19 [==============================] - 42s 2s/step - loss: 0.6112 - accuracy: 0.8010 - recall_with_logits_5: 0.7997 - precision_with_logits_5: 0.9214 - balanced_accuracy: 0.7880 - mcc: 0.5165 - f1: 0.7855 - val_loss: 0.7474 - val_accuracy: 0.6546 - val_recall_with_logits_5: 0.7171 - val_precision_with_logits_5: 0.7951 - val_balanced_accuracy: 0.6889 - val_mcc: 0.3051 - val_f1: 0.7757
# Epoch 194/200
# 19/19 [==============================] - 41s 2s/step - loss: 0.6165 - accuracy: 0.7850 - recall_with_logits_5: 0.7833 - precision_with_logits_5: 0.9138 - balanced_accuracy: 0.7760 - mcc: 0.4883 - f1: 0.7722 - val_loss: 0.7506 - val_accuracy: 0.6316 - val_recall_with_logits_5: 0.6844 - val_precision_with_logits_5: 0.7897 - val_balanced_accuracy: 0.6364 - val_mcc: 0.2727 - val_f1: 0.6875
# Epoch 195/200
# 19/19 [==============================] - 42s 2s/step - loss: 0.6143 - accuracy: 0.8010 - recall_with_logits_5: 0.8006 - precision_with_logits_5: 0.9202 - balanced_accuracy: 0.8313 - mcc: 0.5850 - f1: 0.8239 - val_loss: 0.7426 - val_accuracy: 0.6431 - val_recall_with_logits_5: 0.7051 - val_precision_with_logits_5: 0.7910 - val_balanced_accuracy: 0.6154 - val_mcc: 0.1943 - val_f1: 0.7135
# Epoch 196/200
# 19/19 [==============================] - 41s 2s/step - loss: 0.6068 - accuracy: 0.8076 - recall_with_logits_5: 0.8108 - precision_with_logits_5: 0.9200 - balanced_accuracy: 0.8170 - mcc: 0.5403 - f1: 0.7907 - val_loss: 0.7469 - val_accuracy: 0.6431 - val_recall_with_logits_5: 0.7165 - val_precision_with_logits_5: 0.7810 - val_balanced_accuracy: 0.6135 - val_mcc: 0.2271 - val_f1: 0.6875
# Epoch 197/200
# 19/19 [==============================] - 42s 2s/step - loss: 0.6054 - accuracy: 0.8055 - recall_with_logits_5: 0.8046 - precision_with_logits_5: 0.9221 - balanced_accuracy: 0.7976 - mcc: 0.5169 - f1: 0.7962 - val_loss: 0.7502 - val_accuracy: 0.6398 - val_recall_with_logits_5: 0.7105 - val_precision_with_logits_5: 0.7819 - val_balanced_accuracy: 0.5145 - val_mcc: 0.0281 - val_f1: 0.5999
# Epoch 198/200
# 19/19 [==============================] - 42s 2s/step - loss: 0.6075 - accuracy: 0.8055 - recall_with_logits_5: 0.8115 - precision_with_logits_5: 0.9167 - balanced_accuracy: 0.7322 - mcc: 0.4501 - f1: 0.7616 - val_loss: 0.7472 - val_accuracy: 0.6497 - val_recall_with_logits_5: 0.7267 - val_precision_with_logits_5: 0.7842 - val_balanced_accuracy: 0.3914 - val_mcc: 0.1937 - val_f1: 0.5577
# Epoch 199/200
# 19/19 [==============================] - 42s 2s/step - loss: 0.5997 - accuracy: 0.8109 - recall_with_logits_5: 0.8172 - precision_with_logits_5: 0.9182 - balanced_accuracy: 0.8283 - mcc: 0.6129 - f1: 0.8340 - val_loss: 0.7378 - val_accuracy: 0.6513 - val_recall_with_logits_5: 0.6920 - val_precision_with_logits_5: 0.8073 - val_balanced_accuracy: 0.4909 - val_mcc: 0.0182 - val_f1: 0.5625
# Epoch 200/200
# 19/19 [==============================] - 42s 2s/step - loss: 0.5885 - accuracy: 0.8199 - recall_with_logits_5: 0.8248 - precision_with_logits_5: 0.9242 - balanced_accuracy: 0.8214 - mcc: 0.5768 - f1: 0.8225 - val_loss: 0.7471 - val_accuracy: 0.6464 - val_recall_with_logits_5: 0.7159 - val_precision_with_logits_5: 0.7843 - val_balanced_accuracy: 0.5364 - val_mcc: 0.0778 - val_f1: 0.6123
# CPU times: total: 1h 29min 5s
# Wall time: 1h 53min 40s

# %%
# plot training curve
plt.subplots_adjust(left=0.1,
                    bottom=0.01,
                    right=1.7,
                    top=0.6,
                    wspace=0.4,
                    hspace=0.4)

# metric
plt.subplot(1, 4, 1)
plt.vlines(x=np.argmax(history.history['val_f1']), ymin=0,
           ymax=max(history.history['accuracy'] + history.history['val_accuracy'] + history2.history['f1'] + history2.history['val_f1']), color='red')
plt.plot(history.history['accuracy'] + history2.history['accuracy'])
plt.plot(history.history['val_accuracy'] + history2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(1, 4, 2)
plt.vlines(x=np.argmax(history.history['val_f1']), ymin=0,
           ymax=max(history.history['mcc'] + history.history['val_mcc'] + history2.history['f1'] + history2.history['val_f1']), color='red')
plt.plot(history.history['mcc'] + history2.history['mcc'])
plt.plot(history.history['val_mcc'] + history2.history['val_mcc'])
plt.title('model MCC')
plt.ylabel('MCC')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(1, 4, 3)
plt.vlines(x=np.argmax(history.history['val_f1']), ymin=0,
           ymax=max(history.history['f1'] + history.history['val_f1'] + history2.history['f1'] + history2.history['val_f1']), color='red')
plt.plot(history.history['f1'] + history2.history['f1'])
plt.plot(history.history['val_f1'] + history2.history['val_f1'])
plt.title('model F1')
plt.ylabel('F1')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

# loss
plt.subplot(1, 4, 4)
plt.vlines(x=np.argmax(history.history['val_f1']), ymin=0,
           ymax=max(history.history['loss'] + history.history['val_loss'] + history2.history['loss'] + history2.history['val_loss']), color='red')
plt.plot(history.history['loss'] + history2.history['loss'])
plt.plot(history.history['val_loss'] + history2.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.show()
